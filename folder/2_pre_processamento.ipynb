# %% [markdown]
# # DataFrame
#
#  Usando Pandas, vai ler cada CSV e combinando-os em um único DataFrame.

# %% [markdown]
# 1078 musicas
#
#
# DataFrame combinado: (628446, 9) 628446 linhas e 9 colunas
#
# Cada linha nesse DataFrame representa uma mensagem MIDI individual, capturando um evento específico dentro da música, e não uma música inteira
#
# Formato do DataFrame merged_df: (628446, 10)

# %% [markdown]
# # Colunas e Tipos de Dados:
#
#
# *   **track** (int): Indica a trilha MIDI à qual a mensagem pertence, sendo um número inteiro (0 para a primeira trilha, 1 para a segunda, etc.).
#
# *   **time** (float): Representa o tempo acumulado em segundos desde o início da música até o evento da mensagem MIDI, um valor de ponto flutuante que permite precisão temporal.
#
# *   **type** (object): Descreve o tipo de mensagem MIDI, como 'note_on' (nota tocada), 'note_off' (nota liberada), 'set_tempo' (mudança de andamento), e 'end_of_track' (fim da trilha), sendo um tipo de dado de objeto (string).
#
# *   **channel** (float): O canal MIDI (0-15) ao qual a mensagem se aplica. Valores NaN (Not a Number) podem aparecer para tipos de mensagem que não utilizam um canal (como set_tempo ou end_of_track).
#
# *   **note** (float): O número da nota MIDI (0-127), relevante para mensagens 'note_on' e 'note_off'. Para outros tipos de mensagens, o valor é NaN.
#
# *   **velocity** (float): A intensidade ou volume com que a nota é tocada (0-127), aplicado a mensagens 'note_on' e 'note_off'. Também pode ser NaN para mensagens não relacionadas a notas.
#
# *   **value** (float): Um valor genérico usado por outros tipos de mensagens MIDI, como control_change ou pitchwheel. Geralmente é NaN para mensagens de nota.
#
# *   **tempo** (float): O tempo da música em microssegundos por batida, relevante apenas para mensagens 'set_tempo'. Para a maioria das outras mensagens, será NaN.
#
# *   **music_name** (object): O nome original do arquivo MIDI (sem a extensão .csv), que foi adicionado durante o carregamento para identificar a qual música cada mensagem pertence. ***Esta coluna é crucial para associar os dados da música aos rótulos emocionais.***

# %% [markdown]
# # O QUE FOI FEITO
#
#
# *   Combinação dos CSVs: Todos os arquivos CSV individuais (resultantes da conversão MIDI) são lidos e concatenados em um único e grande DataFrame chamado combined_df. Este DataFrame representa cada mensagem MIDI individual como uma linha, contendo informações como tipo de evento, tempo, nota, velocidade, etc., e o nome da música à qual pertence (music_name)
#
# *   Carregamento e Pré-processamento dos Rótulos Emocionais: O arquivo label.csv fornecido pelo dataset EMOPIA é carregado. As colunas são inspecionadas e, crucialmente, a coluna ID é renomeada para music_name para consistência. Além disso, a categoria emocional (Q1, Q2, Q3 ou Q4) é extraída do music_name e salva em uma nova coluna emotion_quadrant, que servirá como o rótulo (variável alvo) para o modelo de IA
#
#
# *   Merge dos Dados MIDI com os Rótulos: O combined_df (contendo todas as mensagens MIDI) é mesclado com o DataFrame de rótulos (emopia_labels_unique) utilizando a coluna music_name como chave. Isso resulta no merged_df, onde cada mensagem MIDI agora carrega também o rótulo emocional de sua respectiva música. Isso é fundamental, pois permite associar as características de áudio (ou MIDI) com a emoção. Uma verificação é feita para garantir que todas as músicas encontraram seus rótulos
#
#
# *   engenharia de features: Criaçao de novas features. Agrupa o merged_df por música e calcula diversas características estatísticas (como total de eventos, duração, pitch médio, velocidade, etc.) para cada música, consolidando os dados em um features_df onde cada linha representa uma música com suas features e o rótulo de emoção
#
# * Escalonamento/ Normalizaçao das features
#
#
#
# **features_df é salvo no Drive, sendo acessível e reutilizável em futuros Colab para as etapas de treinamento e avaliação de modelos de IA**
#
# **MyDrive/INF 420 - IA/TRABALHO FINAL/dados_processados/emopia_features_with_labels.pkl'**

# %%
import pandas as pd
import os
from google.colab import drive
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
try:
    drive.mount('/content/drive')
    print("Google Drive montado com sucesso.")
except Exception as e:
    print(f"Erro ao montar o Google Drive (pode já estar montado): {e}")
# Out:
# Mounted at /content/drive
# Google Drive montado com sucesso.

# %%
# pasta onde os CSVs foram salvos
#csv_output_folder = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/musicas/CSV'
csv_output_folder = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV'

# %%
# lista para armazenar cada DataFrame lido
all_dataframes = []

# %%
# iterar sobre os arquivos na pasta e carregar cada CSV
print(f"Buscando arquivos CSV na pasta: {csv_output_folder}")
if os.path.exists(csv_output_folder):
    for filename in os.listdir(csv_output_folder):
        if filename.lower().endswith('.csv'):
            file_path = os.path.join(csv_output_folder, filename)
            try:
                df = pd.read_csv(file_path)

                music_name = os.path.splitext(filename)[0]
                df['music_name'] = music_name

                all_dataframes.append(df)
                print(f"Carregado: {filename}")
            except Exception as e:
                print(f"Erro ao carregar '{filename}': {e}")

    if all_dataframes:
        combined_df = pd.concat(all_dataframes, ignore_index=True)
        print("\nTodos os CSVs foram combinados em um único DataFrame.")
        print(f"Formato do DataFrame combinado: {combined_df.shape}")
        #print("Primeiras 5 linhas do DataFrame combinado:")
        #print(combined_df.head())
        #print("\nInformações sobre as colunas e tipos de dados:")
        #combined_df.info()

        # combined_df contem os dados de todas as suas musicas MIDI em um formato tabular pronto para a engenharia de features
    else:
        print("Nenhum arquivo CSV encontrado na pasta especificada ou erro ao carregar.")
else:
    print(f"A pasta '{csv_output_folder}' não foi encontrada. Verifique o caminho ou se os CSVs foram gerados nela.")
# Out:
# Buscando arquivos CSV na pasta: /content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV
# Carregado: Q1_fey-8bOR95E_0.csv
# Carregado: Q1_eVMSeElk81Q_2.csv
# Carregado: Q1_doM_LWo-74A_4.csv
# Carregado: Q1_DX1IK3z1w10_1.csv
# Carregado: Q1_e838BE_MH6s_3.csv
# Carregado: Q1_e838BE_MH6s_2.csv
# Carregado: Q1_e8NQ2NH0nc8_1.csv
# Carregado: Q1_e8NQ2NH0nc8_0.csv
# Carregado: Q1_eVMSeElk81Q_0.csv
# Carregado: Q1_eVMSeElk81Q_1.csv
# Carregado: Q1_e838BE_MH6s_1.csv
# Carregado: Q1_e838BE_MH6s_4.csv
# Carregado: Q1_dfNdpy8TUzA_2.csv
# Carregado: Q1_Cg2u_Ldjv8g_0.csv
# Carregado: Q1_doM_LWo-74A_0.csv
# Carregado: Q1_dfNdpy8TUzA_1.csv
# Carregado: Q1_doM_LWo-74A_2.csv
# Carregado: Q1_Cg2u_Ldjv8g_1.csv
# Carregado: Q1_dfNdpy8TUzA_0.csv
# Carregado: Q1_doM_LWo-74A_3.csv
# Carregado: Q1_doM_LWo-74A_1.csv
# Carregado: Q1_bQS8eAXAhyE_0.csv
# Carregado: Q1_BGf5nCdzPOc_1.csv
# Carregado: Q1_biROWEwkDQQ_3.csv
# Carregado: Q1_bQS8eAXAhyE_1.csv
# Carregado: Q1_bIx4DwkZxFY_1.csv
# Carregado: Q1_BGf5nCdzPOc_0.csv
# Carregado: Q1_bIx4DwkZxFY_0.csv
# Carregado: Q1_bIx4DwkZxFY_2.csv
# Carregado: Q1_bQS8eAXAhyE_2.csv
# Carregado: Q1_cB-Xh8H_7-Q_0.csv
# Carregado: Q1_k4dxAlI5N-k_1.csv
# Carregado: Q1_K6OFDxBU370_0.csv
# Carregado: Q1_JYVXM0qNQAg_0.csv
# Carregado: Q1_jziI_cuN_H8_0.csv
# Carregado: Q1_JT1XJnVmABo_4.csv
# Carregado: Q1_JT1XJnVmABo_5.csv
# Carregado: Q1_JYVXM0qNQAg_2.csv
# Carregado: Q1_jziI_cuN_H8_2.csv
# Carregado: Q1_k4dxAlI5N-k_0.csv
# Carregado: Q1_jziI_cuN_H8_1.csv
# Carregado: Q1_Jn9r0avp0fY_3.csv
# Carregado: Q1_Jn9r0avp0fY_1.csv
# Carregado: Q1_im4Qxn3GQvo_1.csv
# Carregado: Q1_J6X3rVU1H-c_1.csv
# Carregado: Q1_JT1XJnVmABo_2.csv
# Carregado: Q1_J6X3rVU1H-c_2.csv
# Carregado: Q1_im4Qxn3GQvo_2.csv
# Carregado: Q1_Jn9r0avp0fY_0.csv
# Carregado: Q1_Jn9r0avp0fY_2.csv
# Carregado: Q1_JT1XJnVmABo_3.csv
# Carregado: Q1_im4Qxn3GQvo_0.csv
# Carregado: Q1_Ie5koh4qvJc_6.csv
# Carregado: Q1_HY9vPoHbgaI_0.csv
# Carregado: Q1_iFgSjUqI7iM_0.csv
# Carregado: Q1_HY9vPoHbgaI_1.csv
# Carregado: Q1_HY9vPoHbgaI_3.csv
# Carregado: Q1_Ie5koh4qvJc_12.csv
# Carregado: Q1_HY9vPoHbgaI_2.csv
# Carregado: Q1_IH2KrGjKXw0_3.csv
# Carregado: Q1_iFgSjUqI7iM_1.csv
# Carregado: Q1_GY3f6ckBVkA_1.csv
# Carregado: Q1_GY3f6ckBVkA_3.csv
# Carregado: Q1_GY3f6ckBVkA_2.csv
# Carregado: Q1_gSwv8hZGM-s_0.csv
# Carregado: Q1_gSwv8hZGM-s_1.csv
# Carregado: Q1_GbUV3TXUzeQ_2.csv
# Carregado: Q1_GY3f6ckBVkA_0.csv
# Carregado: Q1_GbUV3TXUzeQ_1.csv
# Carregado: Q1_gwmVjvR-sVs_1.csv
# Carregado: Q1_gwmVjvR-sVs_0.csv
# Carregado: Q1_FfwKrQyQ7WU_3.csv
# Carregado: Q1_s5b8viFsVJE_0.csv
# Carregado: Q1_s6-SbDSZzEU_0.csv
# Carregado: Q1_s5b8viFsVJE_2.csv
# Carregado: Q1_s6-SbDSZzEU_1.csv
# Carregado: Q1_SQDuF0qxGQw_2.csv
# Carregado: Q1_UJcnNfeCN1c_3.csv
# Carregado: Q1_SlsXsqotUis_0.csv
# Carregado: Q1_s5b8viFsVJE_1.csv
# Carregado: Q1_SQDuF0qxGQw_0.csv
# Carregado: Q1_sUJ4a74Skk8_0.csv
# Carregado: Q1_RaUSISlnhKw_2.csv
# Carregado: Q1_SQDuF0qxGQw_1.csv
# Carregado: Q1_RaUSISlnhKw_0.csv
# Carregado: Q1_QwsQ8ejbMKg_1.csv
# Carregado: Q1_POaIGvLsp5M_0.csv
# Carregado: Q1_QwsQ8ejbMKg_0.csv
# Carregado: Q1_pNwQ9Tu_bCs_2.csv
# Carregado: Q1_r6laJv1-HMg_0.csv
# Carregado: Q1_qlbazHayULg_8.csv
# Carregado: Q1_POaIGvLsp5M_1.csv
# Carregado: Q1_RaUSISlnhKw_1.csv
# Carregado: Q1_PdwxeMPXOCk_1.csv
# Carregado: Q1_PdwxeMPXOCk_0.csv
# Carregado: Q1_NP0lwB-_-og_1.csv
# Carregado: Q1_pNwQ9Tu_bCs_0.csv
# Carregado: Q1_nOIBJHkqrE8_0.csv
# Carregado: Q1_o5AIp2Yc01M_1.csv
# Carregado: Q1_o5AIp2Yc01M_0.csv
# Carregado: Q1_osxmQReE_2o_0.csv
# Carregado: Q1_pNwQ9Tu_bCs_1.csv
# Carregado: Q1_PdwxeMPXOCk_2.csv
# Carregado: Q1_NGE9ynTJABg_0.csv
# Carregado: Q1_K6OFDxBU370_1.csv
# Carregado: Q1_KxlqB3j0zys_0.csv
# Carregado: Q1_ldCQ6N9G6Mk_2.csv
# Carregado: Q1_KxlqB3j0zys_1.csv
# Carregado: Q1_NGE9ynTJABg_1.csv
# Carregado: Q1_mX-xs3OVhTs_0.csv
# Carregado: Q1_miqLU2739dk_1.csv
# Carregado: Q1_NGE9ynTJABg_2.csv
# Carregado: Q1_mX-xs3OVhTs_1.csv
# Carregado: Q1_yFw_kO7DF-Y_2.csv
# Carregado: Q1_ZgT7yq2jsBk_0.csv
# Carregado: Q1_zHwJG8Rrx6c_0.csv
# Carregado: Q1_zHwJG8Rrx6c_1.csv
# Carregado: Q1_yFw_kO7DF-Y_0.csv
# Carregado: Q1_yFw_kO7DF-Y_1.csv
# Carregado: Q1_zHwJG8Rrx6c_2.csv
# Carregado: Q1_Y5JcZQ0xg4Y_3.csv
# Carregado: Q1_zHwJG8Rrx6c_3.csv
# Carregado: Q1_xrhWli_R98g_3.csv
# Carregado: Q1_XC_SiJszQx0_3.csv
# Carregado: Q1_Wy2-my19YnY_1.csv
# Carregado: Q1_Xsn9zT-05ns_1.csv
# Carregado: Q1_Y5JcZQ0xg4Y_0.csv
# Carregado: Q1_Xsn9zT-05ns_0.csv
# Carregado: Q1_xrhWli_R98g_1.csv
# Carregado: Q1_Y5JcZQ0xg4Y_1.csv
# Carregado: Q1_Y5JcZQ0xg4Y_2.csv
# Carregado: Q1_VXgRfsVd_o0_2.csv
# Carregado: Q1_Wy2-my19YnY_0.csv
# Carregado: Q1_VXgRfsVd_o0_0.csv
# Carregado: Q1_WpZ1rWHOCAQ_0.csv
# Carregado: Q1_WpZ1rWHOCAQ_1.csv
# Carregado: Q1_VXgRfsVd_o0_1.csv
# Carregado: Q1_vv6nrZ2myXw_3.csv
# Carregado: Q1_wnB2cjd6zbE_0.csv
# Carregado: Q1_WpZ1rWHOCAQ_2.csv
# Carregado: Q1_vv6nrZ2myXw_1.csv
# Carregado: Q1_vv6nrZ2myXw_2.csv
# Carregado: Q1_vv6nrZ2myXw_4.csv
# Carregado: Q1_UOSlDydo94E_1.csv
# Carregado: Q1_uqRLEByE6pU_2.csv
# Carregado: Q1_V3Y9L4UOcpk_2.csv
# Carregado: Q1_UYh88SRZC24_0.csv
# Carregado: Q1_uqRLEByE6pU_1.csv
# Carregado: Q1_UYh88SRZC24_1.csv
# Carregado: Q1_uqRLEByE6pU_0.csv
# Carregado: Q1_UOSlDydo94E_2.csv
# Carregado: Q1_UOSlDydo94E_0.csv
# Carregado: Q1_TNoaOTrTkTQ_0.csv
# Carregado: Q1_TNoaOTrTkTQ_1.csv
# Carregado: Q1_T92R7xjce34_1.csv
# Carregado: Q1_UJcnNfeCN1c_2.csv
# Carregado: Q1_sZe3IB1OVfw_0.csv
# Carregado: Q1_TNoaOTrTkTQ_2.csv
# Carregado: Q1_sZe3IB1OVfw_1.csv
# Carregado: Q1_vv6nrZ2myXw_0.csv
# Carregado: Q2_0v2N1ROvEI0_0.csv
# Carregado: Q2_16OaOpfOPZ0_3.csv
# Carregado: Q2_0J7lX-Tcx-w_0.csv
# Carregado: Q2_1EDThWjNxOI_1.csv
# Carregado: Q2_0qYNvMCEwaw_0.csv
# Carregado: Q2_0J7lX-Tcx-w_2.csv
# Carregado: Q2_0v2N1ROvEI0_1.csv
# Carregado: Q2_0J7lX-Tcx-w_1.csv
# Carregado: Q2_38i12IPkL5c_0.csv
# Carregado: Q2_16OaOpfOPZ0_2.csv
# Carregado: Q2_1EDThWjNxOI_0.csv
# Carregado: Q2_08t73Qgjkt4_0.csv
# Carregado: Q2_08t73Qgjkt4_1.csv
# Carregado: Q2_--2B4d4lQhs_0.csv
# Carregado: Q2_-jJVb0xvbdg_0.csv
# Carregado: Q2_--2B4d4lQhs_1.csv
# Carregado: Q2_-jJVb0xvbdg_1.csv
# Carregado: Q2_--2B4d4lQhs_2.csv
# Carregado: Q2_0H4rq0L9OSw_1.csv
# Carregado: Q2_0H4rq0L9OSw_0.csv
# Carregado: Q1__SJQaaRzD-A_1.csv
# Carregado: Q2_08t73Qgjkt4_2.csv
# Carregado: Q1__kJtgm1OUNA_2.csv
# Carregado: Q1__kJtgm1OUNA_1.csv
# Carregado: Q1_zmZHNy9T8Pg_2.csv
# Carregado: Q1__BK2o77sTc0_0.csv
# Carregado: Q1__8v0MFBZoco_0.csv
# Carregado: Q1__BK2o77sTc0_1.csv
# Carregado: Q1__8v0MFBZoco_1.csv
# Carregado: Q1_zmZHNy9T8Pg_0.csv
# Carregado: Q1_zmZHNy9T8Pg_1.csv
# Carregado: Q1__kJtgm1OUNA_0.csv
# Carregado: Q1__SJQaaRzD-A_0.csv
# Carregado: Q2_ANZf1QXsNrY_6.csv
# Carregado: Q2_9v2WSpn4FCw_4.csv
# Carregado: Q2_9v2WSpn4FCw_5.csv
# Carregado: Q2_AWNbcxXDmt0_0.csv
# Carregado: Q2_8TYY0qG-KOw_1.csv
# Carregado: Q2_9v2WSpn4FCw_1.csv
# Carregado: Q2_9v2WSpn4FCw_2.csv
# Carregado: Q2_8c7kcmsnf-s_2.csv
# Carregado: Q2_7n32BtYb4d4_3.csv
# Carregado: Q2_8c7kcmsnf-s_1.csv
# Carregado: Q2_61EA0xRX8gE_1.csv
# Carregado: Q2_7n32BtYb4d4_2.csv
# Carregado: Q2_8c7kcmsnf-s_0.csv
# Carregado: Q2_78C_TpQDvVE_0.csv
# Carregado: Q2_61EA0xRX8gE_4.csv
# Carregado: Q2_61EA0xRX8gE_5.csv
# Carregado: Q2_7n32BtYb4d4_1.csv
# Carregado: Q2_6n8HgIcJ6vo_0.csv
# Carregado: Q2_61EA0xRX8gE_3.csv
# Carregado: Q2_78C_TpQDvVE_1.csv
# Carregado: Q2_9v2WSpn4FCw_3.csv
# Carregado: Q2_3ZnxqCZ7qGg_2.csv
# Carregado: Q2_48EYLEAgaBc_1.csv
# Carregado: Q2_5CEAeMiXKaA_0.csv
# Carregado: Q2_3_MxhSS86oU_0.csv
# Carregado: Q2_3_MxhSS86oU_1.csv
# Carregado: Q2_5NW0zDu6IYM_0.csv
# Carregado: Q2_48EYLEAgaBc_0.csv
# Carregado: Q2_7n32BtYb4d4_0.csv
# Carregado: Q2_3ZnxqCZ7qGg_1.csv
# Carregado: Q2_61EA0xRX8gE_0.csv
# Carregado: Q2_1kny88W533Q_4.csv
# Carregado: Q2_1Q3MoBFh6eU_1.csv
# Carregado: Q2_2uLw9Zs60A4_0.csv
# Carregado: Q2_1kny88W533Q_0.csv
# Carregado: Q2_1kny88W533Q_2.csv
# Carregado: Q2_1TAKQK3s6qQ_0.csv
# Carregado: Q2_5NW0zDu6IYM_1.csv
# Carregado: Q2_1kny88W533Q_3.csv
# Carregado: Q2_38i12IPkL5c_1.csv
# Carregado: Q2_38i12IPkL5c_2.csv
# Carregado: Q2_DYBBfpEx-JI_1.csv
# Carregado: Q2_DYBBfpEx-JI_0.csv
# Carregado: Q2_EtAbPc20mn8_0.csv
# Carregado: Q2_eGQUZ9FlUJ4_0.csv
# Carregado: Q2_DYBBfpEx-JI_2.csv
# Carregado: Q2_epX33OVpkmA_2.csv
# Carregado: Q2_eGQUZ9FlUJ4_1.csv
# Carregado: Q2_DYBBfpEx-JI_3.csv
# Carregado: Q2_epX33OVpkmA_0.csv
# Carregado: Q2_epX33OVpkmA_1.csv
# Carregado: Q2_D5kyjnlDNZs_2.csv
# Carregado: Q2_dtS02mrDMsM_2.csv
# Carregado: Q2_dtS02mrDMsM_4.csv
# Carregado: Q2_dtS02mrDMsM_3.csv
# Carregado: Q2_Dg935IbDggo_1.csv
# Carregado: Q2_Dg935IbDggo_3.csv
# Carregado: Q2_Dg935IbDggo_0.csv
# Carregado: Q2_Dg935IbDggo_2.csv
# Carregado: Q2_dtS02mrDMsM_0.csv
# Carregado: Q2_dtS02mrDMsM_1.csv
# Carregado: Q2_DhnX54kOW8U_0.csv
# Carregado: Q2_D5kyjnlDNZs_1.csv
# Carregado: Q2_CxFXrYgdSSI_1.csv
# Carregado: Q2_cQp1BYDGcRo_1.csv
# Carregado: Q2_D-gDPh9ZpFk_0.csv
# Carregado: Q2_D-gDPh9ZpFk_1.csv
# Carregado: Q2_CxFXrYgdSSI_2.csv
# Carregado: Q2_D-gDPh9ZpFk_2.csv
# Carregado: Q2_CxFXrYgdSSI_0.csv
# Carregado: Q2_cm6E860vDjY_2.csv
# Carregado: Q2_cFWdWpyvwag_0.csv
# Carregado: Q2_cFWdWpyvwag_1.csv
# Carregado: Q2_BzqX-9TA-GY_2.csv
# Carregado: Q2_BzqX-9TA-GY_1.csv
# Carregado: Q2_b8HVQtIoBYU_1.csv
# Carregado: Q2_bfopzItCYrE_1.csv
# Carregado: Q2_cQp1BYDGcRo_0.csv
# Carregado: Q2_D5kyjnlDNZs_0.csv
# Carregado: Q2_9v2WSpn4FCw_6.csv
# Carregado: Q2_AacIP9mDLw8_2.csv
# Carregado: Q2_aYe-2Glruu4_2.csv
# Carregado: Q2_AacIP9mDLw8_0.csv
# Carregado: Q2_ANZf1QXsNrY_7.csv
# Carregado: Q2_9v2WSpn4FCw_8.csv
# Carregado: Q2_9v2WSpn4FCw_7.csv
# Carregado: Q2_cm6E860vDjY_1.csv
# Carregado: Q2_cm6E860vDjY_0.csv
# Carregado: Q2_b8HVQtIoBYU_0.csv
# Carregado: Q2_jrVXitpLGMk_1.csv
# Carregado: Q2_jrVXitpLGMk_2.csv
# Carregado: Q2_JMt4m608s3k_1.csv
# Carregado: Q2_jIKX3ShvLxo_2.csv
# Carregado: Q2_jO2zX6Ul8GM_0.csv
# Carregado: Q2_JMt4m608s3k_2.csv
# Carregado: Q2_jIKX3ShvLxo_1.csv
# Carregado: Q2_JMt4m608s3k_0.csv
# Carregado: Q2_jO2zX6Ul8GM_1.csv
# Carregado: Q2_k4lT-sXg3iI_2.csv
# Carregado: Q2_ivCNV47tsRw_3.csv
# Carregado: Q2_ItGNJM6skM4_1.csv
# Carregado: Q2_Iq6g_4AwUWs_0.csv
# Carregado: Q2_ItGNJM6skM4_2.csv
# Carregado: Q2_ivCNV47tsRw_1.csv
# Carregado: Q2_Iq6g_4AwUWs_1.csv
# Carregado: Q2_ivCNV47tsRw_0.csv
# Carregado: Q2_ivCNV47tsRw_2.csv
# Carregado: Q2_jIKX3ShvLxo_0.csv
# Carregado: Q2_iwxwLEvqeD8_1.csv
# Carregado: Q2_jrVXitpLGMk_0.csv
# Carregado: Q2_Ie5koh4qvJc_7.csv
# Carregado: Q2_Ie5koh4qvJc_11.csv
# Carregado: Q2_Ie5koh4qvJc_26.csv
# Carregado: Q2_Ie5koh4qvJc_10.csv
# Carregado: Q2_Ie5koh4qvJc_13.csv
# Carregado: Q2_GwdQliEv6Z0_1.csv
# Carregado: Q2_ijfxkQPAQdE_1.csv
# Carregado: Q2_Ie5koh4qvJc_30.csv
# Carregado: Q2_Ie5koh4qvJc_9.csv
# Carregado: Q2_ijfxkQPAQdE_2.csv
# Carregado: Q2_gvWDOIiocuE_1.csv
# Carregado: Q2_GwdQliEv6Z0_0.csv
# Carregado: Q2_fuCxYrru2S4_2.csv
# Carregado: Q2_FUAK5TBaNY8_1.csv
# Carregado: Q2_f2BXXa7lPuE_3.csv
# Carregado: Q2_f2BXXa7lPuE_1.csv
# Carregado: Q2_f2BXXa7lPuE_0.csv
# Carregado: Q2_fuCxYrru2S4_1.csv
# Carregado: Q2_ezoAduuCkUs_0.csv
# Carregado: Q2_f2BXXa7lPuE_2.csv
# Carregado: Q2_rEz0D3VohFA_2.csv
# Carregado: Q2_QmK_SND2jAw_1.csv
# Carregado: Q2_qlbazHayULg_6.csv
# Carregado: Q2_rEz0D3VohFA_1.csv
# Carregado: Q2_qlbazHayULg_7.csv
# Carregado: Q2_QmK_SND2jAw_0.csv
# Carregado: Q2_REq37pDAm3A_2.csv
# Carregado: Q2_RiQMuhk_SuQ_2.csv
# Carregado: Q2_RiQMuhk_SuQ_1.csv
# Carregado: Q2_qlbazHayULg_5.csv
# Carregado: Q2_qlbazHayULg_1.csv
# Carregado: Q2_Q5b5unyP8BM_1.csv
# Carregado: Q2_Q5b5unyP8BM_0.csv
# Carregado: Q2_qlbazHayULg_10.csv
# Carregado: Q2_qlbazHayULg_11.csv
# Carregado: Q2_qlbazHayULg_0.csv
# Carregado: Q2_qlbazHayULg_2.csv
# Carregado: Q2_PZN7XLKzLDI_0.csv
# Carregado: Q2_qlbazHayULg_4.csv
# Carregado: Q2_qlbazHayULg_12.csv
# Carregado: Q2_pouxqiySdI8_1.csv
# Carregado: Q2_pouxqiySdI8_0.csv
# Carregado: Q2_P-We4q3goKU_5.csv
# Carregado: Q2_P-We4q3goKU_3.csv
# Carregado: Q2_P-We4q3goKU_6.csv
# Carregado: Q2_OCqMDeD6Fmc_3.csv
# Carregado: Q2_P-We4q3goKU_2.csv
# Carregado: Q2_P-We4q3goKU_1.csv
# Carregado: Q2_P-We4q3goKU_4.csv
# Carregado: Q2_lalnGhxT3PQ_1.csv
# Carregado: Q2_nOIBJHkqrE8_1.csv
# Carregado: Q2_OCqMDeD6Fmc_1.csv
# Carregado: Q2_OCqMDeD6Fmc_2.csv
# Carregado: Q2_OCqMDeD6Fmc_0.csv
# Carregado: Q2_mlHheZbblT0_0.csv
# Carregado: Q2_miqLU2739dk_0.csv
# Carregado: Q2_o20YCzej5_s_0.csv
# Carregado: Q2_lFznCt5kvXM_0.csv
# Carregado: Q2_mlHheZbblT0_1.csv
# Carregado: Q2_lalnGhxT3PQ_0.csv
# Carregado: Q2_kKFwiXKlhC8_1.csv
# Carregado: Q2_kKFwiXKlhC8_0.csv
# Carregado: Q2_l-4Kce3YxxQ_2.csv
# Carregado: Q2_l-4Kce3YxxQ_3.csv
# Carregado: Q2_l-4Kce3YxxQ_0.csv
# Carregado: Q2_L3_TadjSQQ0_1.csv
# Carregado: Q2_l-4Kce3YxxQ_1.csv
# Carregado: Q2_l-4Kce3YxxQ_4.csv
# Carregado: Q2_k-FNDbK6Qhg_2.csv
# Carregado: Q2_jTPXwbDtIpA_2.csv
# Carregado: Q2_JT1XJnVmABo_6.csv
# Carregado: Q2_JYVXM0qNQAg_1.csv
# Carregado: Q2_k4lT-sXg3iI_1.csv
# Carregado: Q2_jTPXwbDtIpA_1.csv
# Carregado: Q2_k4lT-sXg3iI_0.csv
# Carregado: Q2_k-FNDbK6Qhg_0.csv
# Carregado: Q2_Kk60F8a7-Jw_0.csv
# Carregado: Q2_L3_TadjSQQ0_0.csv
# Carregado: Q2_x5ibvz38jOs_0.csv
# Carregado: Q2_WQrPcuy50aA_1.csv
# Carregado: Q2_ufRISSD28XA_1.csv
# Carregado: Q2_WBxql6cuU7c_0.csv
# Carregado: Q2_wfXSdMsd4q8_5.csv
# Carregado: Q2_Uu-oRTRT6uQ_1.csv
# Carregado: Q2_UTo7E0evQWw_0.csv
# Carregado: Q2_UJcnNfeCN1c_1.csv
# Carregado: Q2_Uu-oRTRT6uQ_0.csv
# Carregado: Q2_Uu-oRTRT6uQ_2.csv
# Carregado: Q2_WQrPcuy50aA_0.csv
# Carregado: Q2_UE0y8MHqT-g_2.csv
# Carregado: Q2_snfsc7pEzlk_0.csv
# Carregado: Q2_ufRISSD28XA_0.csv
# Carregado: Q2_UAm0aWvzFI8_0.csv
# Carregado: Q2_TcFVq0leii4_1.csv
# Carregado: Q2_snfsc7pEzlk_1.csv
# Carregado: Q2_snfsc7pEzlk_2.csv
# Carregado: Q2_UAm0aWvzFI8_1.csv
# Carregado: Q2_UE0y8MHqT-g_1.csv
# Carregado: Q2_TcFVq0leii4_2.csv
# Carregado: Q2_sEQf5lcnj_o_3.csv
# Carregado: Q2_S7Bo4-NCEDk_2.csv
# Carregado: Q2_sEQf5lcnj_o_0.csv
# Carregado: Q2_sEQf5lcnj_o_1.csv
# Carregado: Q2_S7Bo4-NCEDk_0.csv
# Carregado: Q2_S1T3UF1vhSk_1.csv
# Carregado: Q2_S7Bo4-NCEDk_1.csv
# Carregado: Q2_S1T3UF1vhSk_2.csv
# Carregado: Q2_sEQf5lcnj_o_2.csv
# Carregado: Q2_RiQMuhk_SuQ_3.csv
# Carregado: Q3_0lEL_XHyhuU_3.csv
# Carregado: Q3_0lEL_XHyhuU_1.csv
# Carregado: Q3_0vLPYiPN7qY_3.csv
# Carregado: Q3_0lEL_XHyhuU_2.csv
# Carregado: Q3_0c2dTJTDUR4_0.csv
# Carregado: Q3_0lEL_XHyhuU_0.csv
# Carregado: Q3_0EWWyyV7RJA_0.csv
# Carregado: Q3_2v6gJi03LlA_0.csv
# Carregado: Q3_16OaOpfOPZ0_1.csv
# Carregado: Q3_16OaOpfOPZ0_0.csv
# Carregado: Q3_02t1bj7ZABY_2.csv
# Carregado: Q2__vZOEQCYSaY_1.csv
# Carregado: Q3_-vAz_HTFEXs_1.csv
# Carregado: Q2__FVzelKlBFs_2.csv
# Carregado: Q3_-vAz_HTFEXs_0.csv
# Carregado: Q3_02t1bj7ZABY_1.csv
# Carregado: Q2__FVzelKlBFs_1.csv
# Carregado: Q2__FVzelKlBFs_0.csv
# Carregado: Q3_0wRQRwnQiqY_0.csv
# Carregado: Q2_ZTrEoB8T9YA_2.csv
# Carregado: Q2_z5ewpQwGDNw_0.csv
# Carregado: Q2_ZTrEoB8T9YA_1.csv
# Carregado: Q2_z5ewpQwGDNw_1.csv
# Carregado: Q3_02t1bj7ZABY_0.csv
# Carregado: Q2__S991V8N-8s_1.csv
# Carregado: Q2_yZGBxiNPu3k_0.csv
# Carregado: Q2_ZdyiXIlKe_Y_0.csv
# Carregado: Q2_yrvKReuwVlY_3.csv
# Carregado: Q2_z5ewpQwGDNw_2.csv
# Carregado: Q2_ZdyiXIlKe_Y_1.csv
# Carregado: Q2_yrvKReuwVlY_2.csv
# Carregado: Q2_ZTrEoB8T9YA_0.csv
# Carregado: Q2_XC_SiJszQx0_1.csv
# Carregado: Q2_yrvKReuwVlY_1.csv
# Carregado: Q2_XfA2KXodrOE_1.csv
# Carregado: Q2_XfA2KXodrOE_0.csv
# Carregado: Q2_yrvKReuwVlY_0.csv
# Carregado: Q2_yhIncZ_Ue4E_1.csv
# Carregado: Q2_x5ibvz38jOs_1.csv
# Carregado: Q2_yhIncZ_Ue4E_2.csv
# Carregado: Q2_yhIncZ_Ue4E_0.csv
# Carregado: Q3_c6CwY8Gbw0c_2.csv
# Carregado: Q3_c6CwY8Gbw0c_3.csv
# Carregado: Q3_BzqX-9TA-GY_0.csv
# Carregado: Q3_c6CwY8Gbw0c_0.csv
# Carregado: Q3_By3JCii1k3w_2.csv
# Carregado: Q3_c6CwY8Gbw0c_1.csv
# Carregado: Q3_c6CwY8Gbw0c_4.csv
# Carregado: Q3_D3onzY4MNxE_0.csv
# Carregado: Q3_D3onzY4MNxE_1.csv
# Carregado: Q3_f0NbGeyJYms_0.csv
# Carregado: Q3_By3JCii1k3w_1.csv
# Carregado: Q3_cCfEDTkuMvg_0.csv
# Carregado: Q3_BIRDDxz0E4c_0.csv
# Carregado: Q3_bfopzItCYrE_0.csv
# Carregado: Q3_bbU31JLtlug_1.csv
# Carregado: Q3_9Xg69XrVaYU_1.csv
# Carregado: Q3_9Xg69XrVaYU_2.csv
# Carregado: Q3_AacIP9mDLw8_1.csv
# Carregado: Q3_Adil-zpJdEs_0.csv
# Carregado: Q3_bbU31JLtlug_0.csv
# Carregado: Q3_9Xg69XrVaYU_0.csv
# Carregado: Q3_By3JCii1k3w_0.csv
# Carregado: Q3_7JIdJLkJ0S4_3.csv
# Carregado: Q3_7JIdJLkJ0S4_1.csv
# Carregado: Q3_4Er-eFHSHA4_1.csv
# Carregado: Q3_77z6Ep3aOmg_0.csv
# Carregado: Q3_7JIdJLkJ0S4_0.csv
# Carregado: Q3_4Er-eFHSHA4_3.csv
# Carregado: Q3_4Er-eFHSHA4_2.csv
# Carregado: Q3_77z6Ep3aOmg_1.csv
# Carregado: Q3_4Er-eFHSHA4_0.csv
# Carregado: Q3_7JIdJLkJ0S4_2.csv
# Carregado: Q3_1Q3MoBFh6eU_2.csv
# Carregado: Q3_1kny88W533Q_1.csv
# Carregado: Q3_3ZnxqCZ7qGg_0.csv
# Carregado: Q3_1Q3MoBFh6eU_0.csv
# Carregado: Q3_2eIsQtm4YNs_1.csv
# Carregado: Q3_1cgO42sh-ZY_0.csv
# Carregado: Q3_2eIsQtm4YNs_0.csv
# Carregado: Q3_2v6gJi03LlA_1.csv
# Carregado: Q3_Ie5koh4qvJc_24.csv
# Carregado: Q3_Ie5koh4qvJc_0.csv
# Carregado: Q3_Ie5koh4qvJc_25.csv
# Carregado: Q3_Ie5koh4qvJc_29.csv
# Carregado: Q3_ii1Jw1-7Ka4_0.csv
# Carregado: Q3_Ie5koh4qvJc_19.csv
# Carregado: Q3_Ie5koh4qvJc_22.csv
# Carregado: Q3_Ie5koh4qvJc_18.csv
# Carregado: Q3_Ie5koh4qvJc_15.csv
# Carregado: Q3_Ie5koh4qvJc_14.csv
# Carregado: Q3_Ie5koh4qvJc_2.csv
# Carregado: Q3_G4rL_OtfFAU_1.csv
# Carregado: Q3_H6_7DjsbROQ_3.csv
# Carregado: Q3_H6_7DjsbROQ_0.csv
# Carregado: Q3_g-yM0Lsp4lc_1.csv
# Carregado: Q3_gvWDOIiocuE_0.csv
# Carregado: Q3_G4rL_OtfFAU_0.csv
# Carregado: Q3_H6_7DjsbROQ_1.csv
# Carregado: Q3_Ie5koh4qvJc_23.csv
# Carregado: Q3_gvWDOIiocuE_2.csv
# Carregado: Q3_H6_7DjsbROQ_4.csv
# Carregado: Q3_FOcdHIhI0_s_0.csv
# Carregado: Q3_FUAK5TBaNY8_0.csv
# Carregado: Q3_FOcdHIhI0_s_1.csv
# Carregado: Q3_fuCxYrru2S4_0.csv
# Carregado: Q3_fnqb8zqHqdY_2.csv
# Carregado: Q3_fnqb8zqHqdY_0.csv
# Carregado: Q3_FUAK5TBaNY8_3.csv
# Carregado: Q3_H6_7DjsbROQ_2.csv
# Carregado: Q3_fnqb8zqHqdY_1.csv
# Carregado: Q3_g-yM0Lsp4lc_0.csv
# Carregado: Q3_FUAK5TBaNY8_2.csv
# Carregado: Q3_egYSmNuIFGk_1.csv
# Carregado: Q3_egYSmNuIFGk_2.csv
# Carregado: Q3_FH28sPhm9Dc_0.csv
# Carregado: Q3_dCoUuknChhE_0.csv
# Carregado: Q3_D8Ed5PZXfF4_0.csv
# Carregado: Q3_DYBBfpEx-JI_4.csv
# Carregado: Q3_epMOLn5Axw0_0.csv
# Carregado: Q3_FH28sPhm9Dc_1.csv
# Carregado: Q3_E5qEloUO3SM_1.csv
# Carregado: Q3_Oku8sIpTMAE_4.csv
# Carregado: Q3_Oku8sIpTMAE_2.csv
# Carregado: Q3_Oku8sIpTMAE_1.csv
# Carregado: Q3_NTI9ode6bRk_1.csv
# Carregado: Q3_NTI9ode6bRk_0.csv
# Carregado: Q3_Oku8sIpTMAE_0.csv
# Carregado: Q3_nFunbdBrukY_0.csv
# Carregado: Q3_nBIls0laAAU_1.csv
# Carregado: Q3_nBIls0laAAU_2.csv
# Carregado: Q3_Oku8sIpTMAE_3.csv
# Carregado: Q3_nBIls0laAAU_0.csv
# Carregado: Q3_nBao46YGZDg_0.csv
# Carregado: Q3_kDGmND1BgmA_1.csv
# Carregado: Q3_MbvPxCUMSek_1.csv
# Carregado: Q3_MbvPxCUMSek_0.csv
# Carregado: Q3_ltxNPJda7zE_2.csv
# Carregado: Q3_ldCQ6N9G6Mk_4.csv
# Carregado: Q3_ldCQ6N9G6Mk_2.csv
# Carregado: Q3_kopwU6zpS4k_0.csv
# Carregado: Q3_MbvPxCUMSek_2.csv
# Carregado: Q3_ldCQ6N9G6Mk_3.csv
# Carregado: Q3_kDGmND1BgmA_0.csv
# Carregado: Q3_JT1XJnVmABo_1.csv
# Carregado: Q3_JNzqL24ZcZ8_2.csv
# Carregado: Q3_K84TcgjCRt4_1.csv
# Carregado: Q3_JNzqL24ZcZ8_1.csv
# Carregado: Q3_jTPXwbDtIpA_0.csv
# Carregado: Q3_K84TcgjCRt4_0.csv
# Carregado: Q3_JNzqL24ZcZ8_0.csv
# Carregado: Q3_K84TcgjCRt4_2.csv
# Carregado: Q3_ItGNJM6skM4_0.csv
# Carregado: Q3_iwxwLEvqeD8_0.csv
# Carregado: Q3_ilCcZpD39HU_3.csv
# Carregado: Q3_ilCcZpD39HU_4.csv
# Carregado: Q3_ilCcZpD39HU_2.csv
# Carregado: Q3_ilCcZpD39HU_0.csv
# Carregado: Q3_iRu9KQvbtVw_0.csv
# Carregado: Q3_ijfxkQPAQdE_0.csv
# Carregado: Q3_ilCcZpD39HU_1.csv
# Carregado: Q3_ii1Jw1-7Ka4_2.csv
# Carregado: Q3_ISCVfmBvYoM_0.csv
# Carregado: Q3_Ie5koh4qvJc_3.csv
# Carregado: Q3_ii1Jw1-7Ka4_1.csv
# Carregado: Q3_IH2KrGjKXw0_1.csv
# Carregado: Q3_Ie5koh4qvJc_5.csv
# Carregado: Q3_IH2KrGjKXw0_2.csv
# Carregado: Q3_IH2KrGjKXw0_0.csv
# Carregado: Q3_Ie5koh4qvJc_8.csv
# Carregado: Q3_uj3Gif77SYM_0.csv
# Carregado: Q3_TonQX8XbvX8_3.csv
# Carregado: Q3_TonQX8XbvX8_2.csv
# Carregado: Q3_TonQX8XbvX8_1.csv
# Carregado: Q3_TonQX8XbvX8_0.csv
# Carregado: Q3_tw_lArYiHTo_0.csv
# Carregado: Q3_TYkTOwBfFB8_1.csv
# Carregado: Q3_TYkTOwBfFB8_0.csv
# Carregado: Q3_UE0y8MHqT-g_0.csv
# Carregado: Q3_tLmXAWfbGqs_0.csv
# Carregado: Q3_uj3Gif77SYM_8.csv
# Carregado: Q3_REq37pDAm3A_4.csv
# Carregado: Q3_RL_cmmNVLfs_0.csv
# Carregado: Q3_RiQMuhk_SuQ_0.csv
# Carregado: Q3_tfuul78deOs_0.csv
# Carregado: Q3_REq37pDAm3A_1.csv
# Carregado: Q3_rEz0D3VohFA_0.csv
# Carregado: Q3_REq37pDAm3A_3.csv
# Carregado: Q3_rrD7XMtPs0Q_0.csv
# Carregado: Q3_S1T3UF1vhSk_0.csv
# Carregado: Q3_tfuul78deOs_1.csv
# Carregado: Q3_qRceKZtwRWA_1.csv
# Carregado: Q3_PXOWy7NiZhk_1.csv
# Carregado: Q3_QJlnTN7HRwE_2.csv
# Carregado: Q3_QJlnTN7HRwE_0.csv
# Carregado: Q3_qlbazHayULg_9.csv
# Carregado: Q3_QJlnTN7HRwE_1.csv
# Carregado: Q3_qlbazHayULg_13.csv
# Carregado: Q3_qlbazHayULg_3.csv
# Carregado: Q3_REq37pDAm3A_0.csv
# Carregado: Q3_QJlnTN7HRwE_3.csv
# Carregado: Q3_OO7zYVeK814_1.csv
# Carregado: Q3_PLfFWFZflQU_1.csv
# Carregado: Q3_P-We4q3goKU_0.csv
# Carregado: Q3_PLfFWFZflQU_0.csv
# Carregado: Q3_pbVGv_g4n50_0.csv
# Carregado: Q3_p2qihp_PnLY_1.csv
# Carregado: Q3_p2qihp_PnLY_0.csv
# Carregado: Q3_PXOWy7NiZhk_0.csv
# Carregado: Q3_OO7zYVeK814_2.csv
# Carregado: Q3_OO7zYVeK814_0.csv
# Carregado: Q3_X1p8xcarVu0_1.csv
# Carregado: Q3_X1p8xcarVu0_0.csv
# Carregado: Q3_x4B0raxVODA_3.csv
# Carregado: Q3_x4B0raxVODA_1.csv
# Carregado: Q3_X1p8xcarVu0_3.csv
# Carregado: Q3_x4B0raxVODA_0.csv
# Carregado: Q3_x4B0raxVODA_2.csv
# Carregado: Q3_xIsvaT20pZ0_1.csv
# Carregado: Q3_wxXpvnmq_-E_0.csv
# Carregado: Q3_xIsvaT20pZ0_0.csv
# Carregado: Q3_wxXpvnmq_-E_2.csv
# Carregado: Q3_wS0RzrBL9UI_1.csv
# Carregado: Q3_wqc8iqbDsGM_4.csv
# Carregado: Q3_wqc8iqbDsGM_0.csv
# Carregado: Q3_wfXSdMsd4q8_0.csv
# Carregado: Q3_vVTP0DOL_2Q_3.csv
# Carregado: Q3_wlOa1jkTn_U_0.csv
# Carregado: Q3_wfXSdMsd4q8_2.csv
# Carregado: Q3_wfXSdMsd4q8_4.csv
# Carregado: Q3_wfXSdMsd4q8_1.csv
# Carregado: Q3_wfXSdMsd4q8_3.csv
# Carregado: Q3_wlOa1jkTn_U_2.csv
# Carregado: Q3_wS0RzrBL9UI_2.csv
# Carregado: Q3_wqc8iqbDsGM_2.csv
# Carregado: Q3_wS0RzrBL9UI_0.csv
# Carregado: Q3_wqc8iqbDsGM_1.csv
# Carregado: Q3_wqc8iqbDsGM_3.csv
# Carregado: Q3_wxXpvnmq_-E_1.csv
# Carregado: Q3_veG92Oi-DlU_0.csv
# Carregado: Q3_veG92Oi-DlU_1.csv
# Carregado: Q3_VrWAZLRdQO8_1.csv
# Carregado: Q3_vVTP0DOL_2Q_0.csv
# Carregado: Q3_veG92Oi-DlU_2.csv
# Carregado: Q3_v2an-9szi8M_0.csv
# Carregado: Q3_wlOa1jkTn_U_1.csv
# Carregado: Q3_vVTP0DOL_2Q_2.csv
# Carregado: Q3_uj3Gif77SYM_7.csv
# Carregado: Q3_uj3Gif77SYM_4.csv
# Carregado: Q3_uj3Gif77SYM_2.csv
# Carregado: Q3_uj3Gif77SYM_5.csv
# Carregado: Q3_vVTP0DOL_2Q_1.csv
# Carregado: Q3_VrWAZLRdQO8_0.csv
# Carregado: Q3_UuLTvhERcnk_1.csv
# Carregado: Q3_UJcnNfeCN1c_0.csv
# Carregado: Q3_uj3Gif77SYM_1.csv
# Carregado: Q3_uj3Gif77SYM_6.csv
# Carregado: Q3_uj3Gif77SYM_3.csv
# Carregado: Q3_UuLTvhERcnk_0.csv
# Carregado: Q4_5DqIntcmdRI_1.csv
# Carregado: Q4_2Z9SjI131jA_6.csv
# Carregado: Q4_2Z9SjI131jA_5.csv
# Carregado: Q4_3As1t6JySDE_0.csv
# Carregado: Q4_1fdxsFbnsX4_1.csv
# Carregado: Q4_1vjy9oMFa8c_1.csv
# Carregado: Q4_1Qc15G0ZHIg_0.csv
# Carregado: Q4_22S3w4idugs_0.csv
# Carregado: Q4_2w5XkAt_3WU_0.csv
# Carregado: Q4_1vjy9oMFa8c_3.csv
# Carregado: Q4_1vjy9oMFa8c_0.csv
# Carregado: Q4_12tDlCQVRtA_0.csv
# Carregado: Q4_1A9Hh2GrDTs_0.csv
# Carregado: Q4_1fdxsFbnsX4_0.csv
# Carregado: Q4_170KC2CbJ7Y_0.csv
# Carregado: Q4_12tDlCQVRtA_2.csv
# Carregado: Q4_-_FjI4bT2Wo_2.csv
# Carregado: Q4_0c2dTJTDUR4_1.csv
# Carregado: Q4_12tDlCQVRtA_1.csv
# Carregado: Q4_-_FjI4bT2Wo_1.csv
# Carregado: Q4_170KC2CbJ7Y_1.csv
# Carregado: Q3_zvWX_dwQPtU_0.csv
# Carregado: Q3__vZOEQCYSaY_0.csv
# Carregado: Q3_zvWX_dwQPtU_2.csv
# Carregado: Q4_-_FjI4bT2Wo_0.csv
# Carregado: Q3__vZOEQCYSaY_2.csv
# Carregado: Q3_ZvD8QSO7NPw_1.csv
# Carregado: Q3_zvWX_dwQPtU_1.csv
# Carregado: Q3__S991V8N-8s_0.csv
# Carregado: Q3_ZvD8QSO7NPw_2.csv
# Carregado: Q4_--2B4d4lQhs_3.csv
# Carregado: Q3_zMa78n8ULtE_1.csv
# Carregado: Q3_yZGBxiNPu3k_1.csv
# Carregado: Q3_xYZ8n8ULaNo_1.csv
# Carregado: Q3_yZGBxiNPu3k_2.csv
# Carregado: Q3_zjr_-ql5Avk_2.csv
# Carregado: Q3_xYZ8n8ULaNo_0.csv
# Carregado: Q3_zjr_-ql5Avk_1.csv
# Carregado: Q3_ZvD8QSO7NPw_0.csv
# Carregado: Q3_zMa78n8ULtE_0.csv
# Carregado: Q3_X1p8xcarVu0_2.csv
# Carregado: Q3_zjr_-ql5Avk_0.csv
# Carregado: Q4_aQ4PIaRMLwE_1.csv
# Carregado: Q4_AjN_5CdVUdw_0.csv
# Carregado: Q4_aQ4PIaRMLwE_0.csv
# Carregado: Q4_aQ4PIaRMLwE_2.csv
# Carregado: Q4_BaHHHgDd0BU_0.csv
# Carregado: Q4_bfopzItCYrE_2.csv
# Carregado: Q4_B3aRl8iTEKw_1.csv
# Carregado: Q4_B3aRl8iTEKw_0.csv
# Carregado: Q4_cXxGBDgFCs8_0.csv
# Carregado: Q4_BIRDDxz0E4c_1.csv
# Carregado: Q4_BaHHHgDd0BU_1.csv
# Carregado: Q4_a5QCcwEjxAk_1.csv
# Carregado: Q4_9eMxCs-LXCE_0.csv
# Carregado: Q4_a5QCcwEjxAk_0.csv
# Carregado: Q4_8TYY0qG-KOw_0.csv
# Carregado: Q4_ADJ_PDauy-g_0.csv
# Carregado: Q4_9eMxCs-LXCE_2.csv
# Carregado: Q4_9v2WSpn4FCw_9.csv
# Carregado: Q4_ADJ_PDauy-g_1.csv
# Carregado: Q4_9eMxCs-LXCE_1.csv
# Carregado: Q4_ADJ_PDauy-g_2.csv
# Carregado: Q4_61EA0xRX8gE_2.csv
# Carregado: Q4_6oLmO9ZSJt0_1.csv
# Carregado: Q4_5J_zI7QE9W8_2.csv
# Carregado: Q4_6oLmO9ZSJt0_0.csv
# Carregado: Q4_5J_zI7QE9W8_1.csv
# Carregado: Q4_6kRPHamGDSo_2.csv
# Carregado: Q4_5J_zI7QE9W8_0.csv
# Carregado: Q4_7yW9c7t8Hq0_0.csv
# Carregado: Q4_7gifuoofgpk_1.csv
# Carregado: Q4_7gifuoofgpk_0.csv
# Carregado: Q4_3TYeU9idRGI_0.csv
# Carregado: Q4_3N2G21U7guk_2.csv
# Carregado: Q4_3N2G21U7guk_0.csv
# Carregado: Q4_5Ju9q1N2x0E_0.csv
# Carregado: Q4_5DqIntcmdRI_0.csv
# Carregado: Q4_3TYeU9idRGI_1.csv
# Carregado: Q4_3N2G21U7guk_1.csv
# Carregado: Q4_3N2G21U7guk_4.csv
# Carregado: Q4_5Ju9q1N2x0E_1.csv
# Carregado: Q4_I2MrA-o5H8I_0.csv
# Carregado: Q4_HYVmgq5Y93g_2.csv
# Carregado: Q4_HYVmgq5Y93g_0.csv
# Carregado: Q4_HYVmgq5Y93g_1.csv
# Carregado: Q4_Hwd6l9jK7bo_1.csv
# Carregado: Q4_Hwd6l9jK7bo_0.csv
# Carregado: Q4_HQ8ISDX6PiI_1.csv
# Carregado: Q4_HQ8ISDX6PiI_0.csv
# Carregado: Q4_hoPp_GLXQis_0.csv
# Carregado: Q4_hoPp_GLXQis_1.csv
# Carregado: Q4_gwmVjvR-sVs_2.csv
# Carregado: Q4_Gcbk0GPT3-g_1.csv
# Carregado: Q4_GAvPwG2wYZM_1.csv
# Carregado: Q4_heBmBQDWj-M_1.csv
# Carregado: Q4_gxsdWKc1QaM_0.csv
# Carregado: Q4_GbUV3TXUzeQ_0.csv
# Carregado: Q4_Gcbk0GPT3-g_0.csv
# Carregado: Q4_heBmBQDWj-M_0.csv
# Carregado: Q4_heBmBQDWj-M_2.csv
# Carregado: Q4_GAvPwG2wYZM_0.csv
# Carregado: Q4_g15aRCHUJEI_2.csv
# Carregado: Q4_fShAWhXIits_1.csv
# Carregado: Q4_FyK_c-TIcCA_1.csv
# Carregado: Q4_FyK_c-TIcCA_2.csv
# Carregado: Q4_FSzOgraSKhs_1.csv
# Carregado: Q4_E5qEloUO3SM_0.csv
# Carregado: Q4_egYSmNuIFGk_0.csv
# Carregado: Q4_FoTXpYZXxJs_1.csv
# Carregado: Q4_g15aRCHUJEI_0.csv
# Carregado: Q4_FSzOgraSKhs_0.csv
# Carregado: Q4_fShAWhXIits_0.csv
# Carregado: Q4_g15aRCHUJEI_1.csv
# Carregado: Q4_FyK_c-TIcCA_0.csv
# Carregado: Q4_fOYX0uH8mSQ_0.csv
# Carregado: Q4_d_49EtXDMFE_1.csv
# Carregado: Q4_E6MARl3zjnQ_0.csv
# Carregado: Q4_d_49EtXDMFE_2.csv
# Carregado: Q4_e838BE_MH6s_0.csv
# Carregado: Q4_f2b4kpdw7_c_0.csv
# Carregado: Q4_f2b4kpdw7_c_1.csv
# Carregado: Q4_Dw7M69CidJ8_0.csv
# Carregado: Q4_DvIH5yUrboc_0.csv
# Carregado: Q4_Dw7M69CidJ8_1.csv
# Carregado: Q4_DvIH5yUrboc_1.csv
# Carregado: Q4_Dw7M69CidJ8_2.csv
# Carregado: Q4_DvIH5yUrboc_2.csv
# Carregado: Q4_d_49EtXDMFE_0.csv
# Carregado: Q4_FoTXpYZXxJs_0.csv
# Carregado: Q4_CkjAksZstEA_1.csv
# Carregado: Q4_Cir1kZyB7QM_0.csv
# Carregado: Q4_CkjAksZstEA_0.csv
# Carregado: Q4_biROWEwkDQQ_1.csv
# Carregado: Q4_biROWEwkDQQ_2.csv
# Carregado: Q4_biROWEwkDQQ_0.csv
# Carregado: Q4_Cir1kZyB7QM_1.csv
# Carregado: Q4_Dw7M69CidJ8_3.csv
# Carregado: Q4_DX1IK3z1w10_0.csv
# Carregado: Q4_cXxGBDgFCs8_1.csv
# Carregado: Q4_cXxGBDgFCs8_2.csv
# Carregado: Q4_kfYaGryaGzI_1.csv
# Carregado: Q4_JT1XJnVmABo_2.csv
# Carregado: Q4_JxSU49jFKwM_0.csv
# Carregado: Q4_JP3QKZlyQz4_0.csv
# Carregado: Q4_JT1XJnVmABo_0.csv
# Carregado: Q4_JP3QKZlyQz4_2.csv
# Carregado: Q4_jO2zX6Ul8GM_2.csv
# Carregado: Q4_jSWItJI-Gmk_0.csv
# Carregado: Q4_jSWItJI-Gmk_1.csv
# Carregado: Q4_JP3QKZlyQz4_1.csv
# Carregado: Q4_jCLgDtk695I_3.csv
# Carregado: Q4_jCLgDtk695I_2.csv
# Carregado: Q4_j8Ir-ssM-AA_0.csv
# Carregado: Q4_jCLgDtk695I_0.csv
# Carregado: Q4_J6X3rVU1H-c_0.csv
# Carregado: Q4_jCLgDtk695I_1.csv
# Carregado: Q4_j8Ir-ssM-AA_1.csv
# Carregado: Q4_JT1XJnVmABo_1.csv
# Carregado: Q4_jNzZCplNNyY_0.csv
# Carregado: Q4_jNzZCplNNyY_1.csv
# Carregado: Q4_IgpNyJVWcBo_0.csv
# Carregado: Q4_Ie5koh4qvJc_32.csv
# Carregado: Q4_iGHgeUCPotc_0.csv
# Carregado: Q4_Ie5koh4qvJc_4.csv
# Carregado: Q4_iHPKusssXzk_1.csv
# Carregado: Q4_iHPKusssXzk_2.csv
# Carregado: Q4_iHPKusssXzk_0.csv
# Carregado: Q4_jCLgDtk695I_4.csv
# Carregado: Q4_iXiSFSGws-c_2.csv
# Carregado: Q4_iXiSFSGws-c_1.csv
# Carregado: Q4_iXiSFSGws-c_0.csv
# Carregado: Q4_Ie5koh4qvJc_16.csv
# Carregado: Q4_Ie5koh4qvJc_17.csv
# Carregado: Q4_Ie5koh4qvJc_1.csv
# Carregado: Q4_I2MrA-o5H8I_1.csv
# Carregado: Q4_I2MrA-o5H8I_2.csv
# Carregado: Q4_Ie5koh4qvJc_20.csv
# Carregado: Q4_Ie5koh4qvJc_28.csv
# Carregado: Q4_Ie5koh4qvJc_21.csv
# Carregado: Q4_Ie5koh4qvJc_27.csv
# Carregado: Q4_Ie5koh4qvJc_31.csv
# Carregado: Q4_nGkpcWNAxDU_1.csv
# Carregado: Q4_MT2_mXn-vGU_1.csv
# Carregado: Q4_MT2_mXn-vGU_0.csv
# Carregado: Q4_nGkpcWNAxDU_0.csv
# Carregado: Q4_lvfNo4KOTmM_1.csv
# Carregado: Q4_mGYKWCVnMwQ_0.csv
# Carregado: Q4_mGYKWCVnMwQ_1.csv
# Carregado: Q4_lTxVVdhFE6Q_1.csv
# Carregado: Q4_lvfNo4KOTmM_0.csv
# Carregado: Q4_OoxI6k0Qsno_1.csv
# Carregado: Q4_MT2_mXn-vGU_2.csv
# Carregado: Q4_lTxVVdhFE6Q_0.csv
# Carregado: Q4_ltxNPJda7zE_0.csv
# Carregado: Q4_ltNK_MY1HkM_1.csv
# Carregado: Q4_ltxNPJda7zE_1.csv
# Carregado: Q4_lQCrA2TE-fo_0.csv
# Carregado: Q4_ltNK_MY1HkM_0.csv
# Carregado: Q4_lQCrA2TE-fo_1.csv
# Carregado: Q4_ltNK_MY1HkM_2.csv
# Carregado: Q4_ltxNPJda7zE_3.csv
# Carregado: Q4_ldCQ6N9G6Mk_5.csv
# Carregado: Q4_ldCQ6N9G6Mk_0.csv
# Carregado: Q4_KxlqB3j0zys_2.csv
# Carregado: Q4_KxlqB3j0zys_3.csv
# Carregado: Q4_KxlqB3j0zys_4.csv
# Carregado: Q4_kMHiU0fhWVw_3.csv
# Carregado: Q4_KRlAez34QfE_2.csv
# Carregado: Q4_ltxNPJda7zE_4.csv
# Carregado: Q4_KRlAez34QfE_0.csv
# Carregado: Q4_KRlAez34QfE_1.csv
# Carregado: Q4_kMHiU0fhWVw_2.csv
# Carregado: Q4_ldCQ6N9G6Mk_1.csv
# Carregado: Q4_kMHiU0fhWVw_1.csv
# Carregado: Q4_kfYaGryaGzI_0.csv
# Carregado: Q4_kMHiU0fhWVw_0.csv
# Carregado: Q4_k6aLLVX1D7Y_0.csv
# Carregado: Q4_k6aLLVX1D7Y_1.csv
# Carregado: Q4_k6aLLVX1D7Y_2.csv
# Carregado: Q4_JxSU49jFKwM_1.csv
# Carregado: Q4_k-FNDbK6Qhg_1.csv
# Carregado: Q4_Tjno89OVuRI_1.csv
# Carregado: Q4_T92R7xjce34_0.csv
# Carregado: Q4_rDhbGjFlKF8_0.csv
# Carregado: Q4_rW1I58_lMEg_2.csv
# Carregado: Q4_rW1I58_lMEg_1.csv
# Carregado: Q4_r_sD61KeUQU_0.csv
# Carregado: Q4_rW1I58_lMEg_0.csv
# Carregado: Q4_rW1I58_lMEg_3.csv
# Carregado: Q4_rDhbGjFlKF8_1.csv
# Carregado: Q4_Tc684nD8CEA_2.csv
# Carregado: Q4_sA9ac1rod84_1.csv
# Carregado: Q4_qRceKZtwRWA_0.csv
# Carregado: Q4_pzeHffxmdcE_0.csv
# Carregado: Q4_pRuwHN-lI44_3.csv
# Carregado: Q4_q4T8Znozvkk_0.csv
# Carregado: Q4_pRuwHN-lI44_1.csv
# Carregado: Q4_QBJ6YYYpIyk_0.csv
# Carregado: Q4_PZN7XLKzLDI_1.csv
# Carregado: Q4_Q49PWE0RJLY_0.csv
# Carregado: Q4_pRuwHN-lI44_2.csv
# Carregado: Q4_sA9ac1rod84_0.csv
# Carregado: Q4_OUb9uaOlWAM_0.csv
# Carregado: Q4_pRuwHN-lI44_0.csv
# Carregado: Q4_PK8YIUaV3Xw_1.csv
# Carregado: Q4_prUUays30Mg_0.csv
# Carregado: Q4_OyaY4213c2A_0.csv
# Carregado: Q4_pkz8OkWhwnk_1.csv
# Carregado: Q4_Q49PWE0RJLY_1.csv
# Carregado: Q4_OyaY4213c2A_1.csv
# Carregado: Q4_PK8YIUaV3Xw_0.csv
# Carregado: Q4_pkz8OkWhwnk_0.csv
# Carregado: Q4_oTi57hZfArE_1.csv
# Carregado: Q4_prUUays30Mg_1.csv
# Carregado: Q4_NP0lwB-_-og_0.csv
# Carregado: Q4_OoxI6k0Qsno_0.csv
# Carregado: Q4_oTi57hZfArE_0.csv
# Carregado: Q4_NzJjMGJg1wE_0.csv
# Carregado: Q4_nGkpcWNAxDU_2.csv
# Carregado: Q4_OgkB7PfqWzA_0.csv
# Carregado: Q4_OgkB7PfqWzA_1.csv
# Carregado: Q4_oTi57hZfArE_2.csv
# Carregado: Q4_vBHoSz8cJIE_3.csv
# Carregado: Q4_VCSDjQxAJzc_0.csv
# Carregado: Q4_vBHoSz8cJIE_2.csv
# Carregado: Q4_vBHoSz8cJIE_4.csv
# Carregado: Q4_vBHoSz8cJIE_1.csv
# Carregado: Q4_VCSDjQxAJzc_1.csv
# Carregado: Q4_VCSDjQxAJzc_2.csv
# Carregado: Q4_Xf2fox7zhCQ_0.csv
# Carregado: Q4_vpTguZtJAFA_0.csv
# Carregado: Q4_vJ77eDxHezE_1.csv
# Carregado: Q4_Ury1cdB79s0_0.csv
# Carregado: Q4_u_7b9CwyM8Q_0.csv
# Carregado: Q4_vJ77eDxHezE_0.csv
# Carregado: Q4_v3Nl5rUxLqE_0.csv
# Carregado: Q4_v3Nl5rUxLqE_1.csv
# Carregado: Q4_Ury1cdB79s0_1.csv
# Carregado: Q4_V3Y9L4UOcpk_1.csv
# Carregado: Q4_uUtnyA6tLnI_0.csv
# Carregado: Q4_V3Y9L4UOcpk_0.csv
# Carregado: Q4_u_7b9CwyM8Q_1.csv
# Carregado: Q4_vBHoSz8cJIE_0.csv
# Carregado: Q4_UaYYMRkHMYc_1.csv
# Carregado: Q4_UbKAl4roB8k_1.csv
# Carregado: Q4_TOXg4-ZGb-g_2.csv
# Carregado: Q4_UbKAl4roB8k_2.csv
# Carregado: Q4_UaYYMRkHMYc_2.csv
# Carregado: Q4_UbKAl4roB8k_0.csv
# Carregado: Q4_UpHutdJvZMI_2.csv
# Carregado: Q4_UaYYMRkHMYc_0.csv
# Carregado: Q4_UpHutdJvZMI_1.csv
# Carregado: Q4_UpHutdJvZMI_0.csv
# Carregado: Q4_TOXg4-ZGb-g_1.csv
# Carregado: Q4_TOXg4-ZGb-g_0.csv
# Carregado: Q4_Tc684nD8CEA_4.csv
# Carregado: Q4_Tc684nD8CEA_0.csv
# Carregado: Q4_Tc684nD8CEA_1.csv
# Carregado: Q4_Tc684nD8CEA_3.csv
# Carregado: Q4_TcFVq0leii4_0.csv
# Carregado: Q4_Tjno89OVuRI_0.csv
# Carregado: Q4_yC0fAQxGgr0_0.csv
# Carregado: Q4_Y1F0c3zgMJo_0.csv
# Carregado: Q4_yC0fAQxGgr0_1.csv
# Carregado: Q4_Y1F0c3zgMJo_1.csv
# Carregado: Q4__BK2o77sTc0_2.csv
# Carregado: Q4_YAAxPW1GB7w_0.csv
# Carregado: Q4_YAAxPW1GB7w_1.csv
# Carregado: Q4_XWk5XUEBXmg_1.csv
# Carregado: Q4_XWk5XUEBXmg_0.csv
# Carregado: Q4_XPLYvpyfKUM_0.csv
# Carregado: Q4_Xlv4PPGrRRs_0.csv
# Carregado: Q4_xgtwQGeB6_0_0.csv
# Carregado: Q4_XPLYvpyfKUM_1.csv
# Carregado: Q4_Xf2fox7zhCQ_2.csv
# Carregado: Q4_xrhWli_R98g_0.csv
# Carregado: Q4_Xlv4PPGrRRs_1.csv
# Carregado: Q4_YhXRyOl5pi0_0.csv
# Carregado: Q4_vpTguZtJAFA_1.csv
# Carregado: Q4_Xf2fox7zhCQ_1.csv
# Carregado: Q4_V_jbWvQNh5c_1.csv
# Carregado: Q4_V_jbWvQNh5c_0.csv
# Carregado: Q4_XC_SiJszQx0_2.csv
# Carregado: Q4_wzSr6qR3Ra0_0.csv
# Carregado: Q4_XC_SiJszQx0_0.csv
# Carregado: Q4_VXh4IaR5C6s_0.csv
# Carregado: Q4_vpTguZtJAFA_2.csv
# Carregado: Q4_xrhWli_R98g_2.csv
# Carregado: Q1_4dXC1cC7crw_0.csv
# Carregado: Q1_2Z9SjI131jA_2.csv
# Carregado: Q1_2Z9SjI131jA_14.csv
# Carregado: Q1_2Z9SjI131jA_10.csv
# Carregado: Q1_2Z9SjI131jA_3.csv
# Carregado: Q1_2Z9SjI131jA_13.csv
# Carregado: Q1_2Z9SjI131jA_12.csv
# Carregado: Q1_3N2G21U7guk_3.csv
# Carregado: Q1_2Z9SjI131jA_11.csv
# Carregado: Q1_2Z9SjI131jA_15.csv
# Carregado: Q1_2Z9SjI131jA_1.csv
# Carregado: Q1_1vjy9oMFa8c_5.csv
# Carregado: Q1_0vLPYiPN7qY_1.csv
# Carregado: Q1_1Qc15G0ZHIg_1.csv
# Carregado: Q1_1Qc15G0ZHIg_3.csv
# Carregado: Q1_2Z9SjI131jA_0.csv
# Carregado: Q1_0vLPYiPN7qY_2.csv
# Carregado: Q1_0vLPYiPN7qY_0.csv
# Carregado: Q1_1Qc15G0ZHIg_2.csv
# Carregado: Q1_1vjy9oMFa8c_2.csv
# Carregado: Q1_2Z9SjI131jA_4.csv
# Carregado: Q1_1vjy9oMFa8c_4.csv
# Carregado: Q1_ANZf1QXsNrY_0.csv
# Carregado: Q1_ANZf1QXsNrY_5.csv
# Carregado: Q1_ANZf1QXsNrY_3.csv
# Carregado: Q1_aYe-2Glruu4_4.csv
# Carregado: Q1_ANZf1QXsNrY_2.csv
# Carregado: Q1_ANZf1QXsNrY_1.csv
# Carregado: Q1_ANZf1QXsNrY_4.csv
# Carregado: Q1_aYe-2Glruu4_0.csv
# Carregado: Q1_9Yb9OEVwups_0.csv
# Carregado: Q1_aYe-2Glruu4_1.csv
# Carregado: Q1_aYe-2Glruu4_3.csv
# Carregado: Q1_9v2WSpn4FCw_5.csv
# Carregado: Q1_94ROf10d1iA_3.csv
# Carregado: Q1_9v2WSpn4FCw_2.csv
# Carregado: Q1_9v2WSpn4FCw_0.csv
# Carregado: Q1_9v2WSpn4FCw_10.csv
# Carregado: Q1_9v2WSpn4FCw_6.csv
# Carregado: Q1_94ROf10d1iA_1.csv
# Carregado: Q1_9v2WSpn4FCw_1.csv
# Carregado: Q1_94ROf10d1iA_0.csv
# Carregado: Q1_8rupdevqfuI_2.csv
# Carregado: Q1_94ROf10d1iA_2.csv
# Carregado: Q1_6Uf9XBUD3wE_1.csv
# Carregado: Q1_7yW9c7t8Hq0_3.csv
# Carregado: Q1_7yW9c7t8Hq0_2.csv
# Carregado: Q1_7yW9c7t8Hq0_1.csv
# Carregado: Q1_6wFJhmhNeeg_0.csv
# Carregado: Q1_8izVTDgBQPc_1.csv
# Carregado: Q1_8izVTDgBQPc_0.csv
# Carregado: Q1_8rupdevqfuI_0.csv
# Carregado: Q1_8rupdevqfuI_1.csv
# Carregado: Q1_6kRPHamGDSo_0.csv
# Carregado: Q1_4ydjOX3pWds_0.csv
# Carregado: Q1_5Ju9q1N2x0E_2.csv
# Carregado: Q1_6Uf9XBUD3wE_0.csv
# Carregado: Q1_6kRPHamGDSo_1.csv
# Carregado: Q1_6kRPHamGDSo_3.csv
# Carregado: Q1_2Z9SjI131jA_7.csv
# Carregado: Q1_3N2G21U7guk_6.csv
# Carregado: Q1_2Z9SjI131jA_8.csv
# Carregado: Q1_3ahg_eQZhxs_1.csv
# Carregado: Q1_3N2G21U7guk_5.csv
# Carregado: Q1_4dXC1cC7crw_1.csv
# Carregado: Q1_3ahg_eQZhxs_0.csv
# Carregado: Q1_2Z9SjI131jA_9.csv
# Carregado: Q1_4ydjOX3pWds_1.csv
# Carregado: Q1_5NW0zDu6IYM_2.csv
# Carregado: Q1_60LLKmpgzRM_0.csv
# Carregado: Q1_FfwKrQyQ7WU_1.csv
# Carregado: Q1_FfwKrQyQ7WU_0.csv
# Carregado: Q1_fey-8bOR95E_1.csv
# Carregado: Q1_FfwKrQyQ7WU_2.csv
# Carregado: Q1_Fc1qk52SaKY_1.csv
# Carregado: Q1_Fc1qk52SaKY_0.csv
# Carregado: Q1_fey-8bOR95E_3.csv
# Carregado: Q1_fey-8bOR95E_2.csv
#
# Todos os CSVs foram combinados em um único DataFrame.
# Formato do DataFrame combinado: (628446, 9)

# %%
combined_df.shape
# Out:
# (628446, 9)

# %%
combined_df.tail(5)
# Out:
#         track       time          type  channel  note  velocity  value  tempo  \
# 628441      1  29.401042       note_on      0.0  55.0       0.0    NaN    NaN
# 628442      1  29.401042       note_on      0.0  60.0       0.0    NaN    NaN
# 628443      1  29.401042       note_on      0.0  64.0       0.0    NaN    NaN
# 628444      1  29.401042       note_on      0.0  67.0       0.0    NaN    NaN
# 628445      1  29.402344  end_of_track      NaN   NaN       NaN    NaN    NaN
#
#               music_name
# 628441  Q1_fey-8bOR95E_2
# 628442  Q1_fey-8bOR95E_2
# 628443  Q1_fey-8bOR95E_2
# 628444  Q1_fey-8bOR95E_2
# 628445  Q1_fey-8bOR95E_2

# %%
combined_df.head(5)
# Out:
#    track      time            type  channel  note  velocity  value     tempo  \
# 0      0  0.000000       set_tempo      NaN   NaN       NaN    NaN  500000.0
# 1      0  0.000000  time_signature      NaN   NaN       NaN    NaN       NaN
# 2      0  0.001302    end_of_track      NaN   NaN       NaN    NaN       NaN
# 3      1  0.130208         note_on      0.0  71.0      78.0    NaN       NaN
# 4      1  0.139323         note_on      0.0  57.0      69.0    NaN       NaN
#
#          music_name
# 0  Q1_fey-8bOR95E_0
# 1  Q1_fey-8bOR95E_0
# 2  Q1_fey-8bOR95E_0
# 3  Q1_fey-8bOR95E_0
# 4  Q1_fey-8bOR95E_0

# %%
#ver quantas musicas tem
print(combined_df['music_name'].unique())
print(f"Total de músicas únicas carregadas: {len(combined_df['music_name'].unique())}")
# Out:
# ['Q1_fey-8bOR95E_0' 'Q1_eVMSeElk81Q_2' 'Q1_doM_LWo-74A_4' ...
#  'Q1_Fc1qk52SaKY_0' 'Q1_fey-8bOR95E_3' 'Q1_fey-8bOR95E_2']
# Total de músicas únicas carregadas: 1078

# %% [markdown]
# # USANDO label.csv

# %% [markdown]
# * Drive: acessa os arquivos do dataset EMOPIA
# * carrega o arquivo label.csv, que contém os rótulos emocionais associados a cada música do dataset
# * processa esse arquivo de rótulos, coluna de id da música --> music_name e extraindo a categoria emocional (Q1, Q2, Q3, Q4) diretamente do nome de cada arquivo
# * fusão desses rótulos emocionais com o combined_df, contém todas as mensagens MIDI de cada música
#
# * Agora, cada mensagem MIDI ta diretamente associada ao quadrante emocional da música

# %%
try:
    drive.mount('/content/drive')
except Exception as e:
    print(f"Drive already mounted or error: {e}")


emopia_labels_path = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/EMOPIA_1.0/EMOPIA_1.0/label.csv'

if os.path.exists(emopia_labels_path):
    emopia_labels_df = pd.read_csv(emopia_labels_path)
    print("DataFrame de rótulos EMOPIA (label.csv) carregado com sucesso.")
    print("Primeiras 5 linhas do DataFrame de rótulos:")
    print(emopia_labels_df.head())
    print(f"Colunas do DataFrame de rótulos: {emopia_labels_df.columns.tolist()}")
else:
    print(f"ERRO: Arquivo de rótulos EMOPIA (label.csv) NÃO FOI ENCONTRADO em: {emopia_labels_path}")
    exit()

# --- PREPARAÇÃO PARA O MERGE ---

# renomear a coluna 'ID' para 'music_name'
# rodando pela segunda vez: ja trocou nome
#emopia_labels_df = emopia_labels_df.rename(columns={'ID': 'music_name'})

# extrair emoção (Q1, Q2, Q3, Q4) da coluna 'music_name'
emopia_labels_df['emotion_quadrant'] = emopia_labels_df['music_name'].str.split('_').str[0]


emopia_labels_unique = emopia_labels_df[['music_name', 'emotion_quadrant']].drop_duplicates()

print("\nDataFrame de rótulos preparado para merge:")
print(emopia_labels_unique.head())
print(f"Número de músicas únicas no DataFrame de rótulos: {len(emopia_labels_unique)}")

merged_df = pd.merge(combined_df, emopia_labels_unique, on='music_name', how='left')


print("\nDataFrame combinado com rótulos emocionais (merged_df):")
print(f"Formato do DataFrame merged_df: {merged_df.shape}")
print("Primeiras 10 linhas do DataFrame merged_df (com rótulos):")
print(merged_df.head(10))

# verifica se todas as músicas encontraram um rótulo
nan_labels = merged_df['emotion_quadrant'].isnull().sum()
if nan_labels > 0:
    print(f"\nATENÇÃO: {nan_labels} linhas no merged_df têm rótulos ausentes (NaN) na coluna 'emotion_quadrant'.")
    print("Isso pode indicar que algumas músicas no seu combined_df não foram encontradas no label.csv.")
else:
    print("\nTodos os arquivos MIDI no combined_df foram rotulados com sucesso!")

print("\nContagem de músicas por quadrante de emoção:")
print(merged_df['emotion_quadrant'].value_counts())
# Out:
# Drive already mounted or error: name 'drive' is not defined
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-371533486.py in <cell line: 0>()
#       7 emopia_labels_path = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/EMOPIA_1.0/EMOPIA_1.0/label.csv'
#       8
# ----> 9 if os.path.exists(emopia_labels_path):
#      10     emopia_labels_df = pd.read_csv(emopia_labels_path)
#      11     print("DataFrame de rótulos EMOPIA (label.csv) carregado com sucesso.")
#
# NameError: name 'os' is not defined

# %% [markdown]
# # ENGENHARIA DE FEATURES
#
# salvar para um novo colab o dataFrame features_df
#
# ADICIONANDO NOVAS FEATURES
#
# - note_density (Densidade de Notas)
#   - total_midi_events / duration
# - note_on_proportion (Proporção de Eventos Note_On)
#   - num_note_on_events / total_midi_events
# - std_time_diff_between_notes (Variação Rítmica)
#   - Calcula a diferença entre os times de eventos note_on consecutivos usando diff() e retorna o desvio padrão dessas diferenças de tempo

# %%
# agrupar por music_name e extrair features
features_df = merged_df.groupby('music_name').agg(
    total_midi_events=('type', 'count'),
    duration=('time', lambda x: x.max() if x.max() > 0 else 0),
    num_unique_tracks=('track', 'nunique'),
    num_unique_channels=('channel', 'nunique'),
    avg_note_pitch=('note', 'mean'),
    std_note_pitch=('note', 'std'),
    min_note_pitch=('note', 'min'),
    max_note_pitch=('note', 'max'),
    pitch_range=('note', lambda x: x.max() - x.min() if pd.notna(x.max()) and pd.notna(x.min()) else 0), # Melhorar o tratamento de NaNs para pitch_range
    avg_note_velocity=('velocity', 'mean'),
    std_note_velocity=('velocity', 'std'),
    num_note_on_events=('type', lambda x: (x == 'note_on').sum()),
    num_note_off_events=('type', lambda x: (x == 'note_off').sum()),
    num_set_tempo_events=('type', lambda x: (x == 'set_tempo').sum()),
    emotion_quadrant=('emotion_quadrant', 'first')
).reset_index()

# ----------------- NOVAS FEATURES -------------------

# Densidade de notas: total_midi_events / duration
# garantir que 'duration' != zero
features_df['note_density'] = features_df.apply(
    lambda row: row['total_midi_events'] / row['duration'] if row['duration'] > 0 else 0,
    axis=1
)


# Proporção de eventos note_on: num_note_on_events / total_midi_events
# 'total_midi_events' não seja zero
features_df['note_on_proportion'] = features_df.apply(
    lambda row: row['num_note_on_events'] / row['total_midi_events'] if row['total_midi_events'] > 0 else 0,
    axis=1
)


# Variação rítmica: std_time_diff_between_notes
# Isso requer um passo adicional, pois precisamos do 'time' dos eventos 'note_on' para cada música
# Vamos agrupar novamente para calcular isso de forma mais eficiente

def calculate_rhythmic_std(group):
    # Filtra apenas eventos 'note_on'
    note_on_times = group[group['type'] == 'note_on']['time']
    if len(note_on_times) > 1:
        time_diffs = note_on_times.diff().dropna()
        if len(time_diffs) > 0:
            return time_diffs.std()
    return 0

# Aplicar a função customizada para cada grupo de música no merged_df
rhythmic_std = merged_df.groupby('music_name').apply(calculate_rhythmic_std).reset_index(name='std_time_diff_between_notes')


features_df = pd.merge(features_df, rhythmic_std, on='music_name', how='left')

# Certifique-se de preencher NaNs para 'std_time_diff_between_notes' também, caso alguma música não tenha notas suficientes
features_df['std_time_diff_between_notes'] = features_df['std_time_diff_between_notes'].fillna(0)



# tratamento de NaNs para as features numéricas
# NaNs --> 0 para features numéricas, exceto para 'emotion_quadrant'
# 'pitch_range' e 'std_note_pitch' podem ser NaN se houver poucas notas.
for col in ['avg_note_pitch', 'std_note_pitch', 'min_note_pitch', 'max_note_pitch', 'pitch_range',
            'avg_note_velocity', 'std_note_velocity', 'note_density', 'note_on_proportion', 'std_time_diff_between_notes']:
    if col in features_df.columns:
        features_df[col] = features_df[col].fillna(0)


print("\nDataFrame de Features por Música (features_df):")
print(f"Formato do DataFrame features_df: {features_df.shape}")
print("Primeiras 5 linhas do DataFrame features_df:")
print(features_df.head())

print("\nContagem de Músicas por Quadrante no features_df:")
print(features_df['emotion_quadrant'].value_counts())
print(f"Total de músicas únicas no features_df: {len(features_df)}")

# %%
features_df.shape

# %% [markdown]
# # Escalonamento/Normalização das Features

# %%
numeric_features = features_df.select_dtypes(include=['number']).columns.tolist()

scaler = StandardScaler()
features_df[numeric_features] = scaler.fit_transform(features_df[numeric_features])


print("\nDataFrame de Features Escaladas (features_df):")
print(features_df.head())

# %% [markdown]
# # salvar no drive

# %%
output_directory = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/dados_processados/'
output_filename = 'emopia_features_with_labels.pkl' # 2 opçoes: .pkl ou .parquet
output_path = os.path.join(output_directory, output_filename)

os.makedirs(output_directory, exist_ok=True)

features_df.to_pickle(output_path)  # .pkl
# Ou: features_df.to_parquet(output_path, index=False) # Para .parquet (requer `pip install pyarrow`)

print(f"\nDataFrame de features salvo com sucesso em: {output_path}")

# %%
output_directory = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/dados_processados/'
output_filename_csv = 'emopia_features_with_labels.csv'
output_path_csv = os.path.join(output_directory, output_filename_csv)
features_df.to_csv(output_path_csv, index=False)
print(f"DataFrame de features salvo em CSV: {output_path_csv}")
