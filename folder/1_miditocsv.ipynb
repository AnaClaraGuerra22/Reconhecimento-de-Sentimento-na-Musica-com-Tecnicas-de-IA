# %%
pip install mido python-rtmidi
# Out:
# Requirement already satisfied: mido in /usr/local/lib/python3.11/dist-packages (1.3.3)
# Requirement already satisfied: python-rtmidi in /usr/local/lib/python3.11/dist-packages (1.5.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido) (24.2)

# %%
from google.colab import drive
drive.mount('/content/drive')

import mido
import csv
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def midi_to_csv(midi_file_path, csv_output_path):
    """
    Converte um arquivo MIDI para CSV.

    Cada linha no CSV representa uma mensagem MIDI com os seguintes campos:
    - track: O índice da trilha MIDI (0, 1, 2, ...)
    - time: O tempo em segundos (acumulado a partir do início do arquivo MIDI)
    - type: O tipo da mensagem MIDI (e.g., 'note_on', 'note_off', 'set_tempo')
    - channel: O canal MIDI (se aplicável)
    - note: O número da nota MIDI (se aplicável)
    - velocity: A velocidade da nota MIDI (se aplicável)
    - value: O valor para mensagens como 'control_change', 'pitchwheel', etc.
    - tempo: O tempo em microssegundos por batida (para mensagens 'set_tempo')
    """
    try:
        mid = mido.MidiFile(midi_file_path)
    except Exception as e:
        print(f"Erro ao abrir o arquivo MIDI {midi_file_path}: {e}")
        return

    with open(csv_output_path, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['track', 'time', 'type', 'channel', 'note', 'velocity', 'value', 'tempo']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()

        current_time_seconds = 0.0  # tempo acumulado em segundos
        # tempo padrão (500000 microsegundos/beat = 120 BPM)
        microseconds_per_beat = mido.bpm2tempo(120)

        for i, track in enumerate(mid.tracks):
            for msg in track:
                # msg.time é o tempo delta em ticks
                delta_ticks = msg.time

                # 'set_tempo', atualiza o tempo por batida
                if msg.type == 'set_tempo':
                    microseconds_per_beat = msg.tempo

                # tempo em segundos para este delta de ticks
                # time_in_seconds = (delta_ticks / mid.ticks_per_beat) * (microseconds_per_beat / 1_000_000)
                # mido oferece uma função auxiliar para isso:
                delta_time_in_seconds = mido.tick2second(delta_ticks, mid.ticks_per_beat, microseconds_per_beat)

                current_time_seconds += delta_time_in_seconds

                row = {
                    'track': i,
                    'time': current_time_seconds,
                    'type': msg.type,
                    'channel': getattr(msg, 'channel', ''),
                    'note': getattr(msg, 'note', ''),
                    'velocity': getattr(msg, 'velocity', ''),
                    'value': getattr(msg, 'value', ''),
                    'tempo': getattr(msg, 'tempo', ''), # Este campo mostrará o tempo se for uma msg 'set_tempo'
                }
                writer.writerow(row)
    print(f"Arquivo '{midi_file_path}' convertido para '{csv_output_path}'")

# %%
def convert_multiple_midis_to_csvs(input_folder, output_folder):
    """
    Converte todos os arquivos MIDI em uma pasta de entrada para CSVs em uma pasta de saída.
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith('.mid') or filename.lower().endswith('.midi'):
            midi_file_path = os.path.join(input_folder, filename)
            csv_filename = os.path.splitext(filename)[0] + '.csv'
            csv_output_path = os.path.join(output_folder, csv_filename)
            midi_to_csv(midi_file_path, csv_output_path)

# %%
# !pip install mido python-rtmidi
# Out:
# Requirement already satisfied: mido in /usr/local/lib/python3.11/dist-packages (1.3.3)
# Requirement already satisfied: python-rtmidi in /usr/local/lib/python3.11/dist-packages (1.5.8)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mido) (24.2)

# %%
# caminhos para o Google Drive
# input_midi_folder = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/musicas/MIDI/MIDI 2'  # tem MIDI 1 e MIDI 2
# output_csv_folder = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/musicas/CSV'
input_midi_folder = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA'
output_csv_folder = '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV'


if not os.path.exists(output_csv_folder):
    os.makedirs(output_csv_folder)
    print(f"Pasta de saída '{output_csv_folder}' criada no seu Google Drive")

#convert_multiple_midis_to_csvs(input_midi_folder, output_csv_folder)

# %%
convert_multiple_midis_to_csvs(input_midi_folder, output_csv_folder)
# Out:
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_4dXC1cC7crw_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_4dXC1cC7crw_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_14.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_14.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_10.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_10.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_13.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_13.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_12.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_12.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_3N2G21U7guk_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_3N2G21U7guk_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_11.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_11.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_15.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_15.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_1vjy9oMFa8c_5.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_1vjy9oMFa8c_5.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_0vLPYiPN7qY_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_0vLPYiPN7qY_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_1Qc15G0ZHIg_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_1Qc15G0ZHIg_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_1Qc15G0ZHIg_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_1Qc15G0ZHIg_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_0vLPYiPN7qY_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_0vLPYiPN7qY_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_0vLPYiPN7qY_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_0vLPYiPN7qY_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_1Qc15G0ZHIg_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_1Qc15G0ZHIg_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_1vjy9oMFa8c_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_1vjy9oMFa8c_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_1vjy9oMFa8c_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_1vjy9oMFa8c_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ANZf1QXsNrY_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ANZf1QXsNrY_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ANZf1QXsNrY_5.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ANZf1QXsNrY_5.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ANZf1QXsNrY_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ANZf1QXsNrY_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_aYe-2Glruu4_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_aYe-2Glruu4_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ANZf1QXsNrY_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ANZf1QXsNrY_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ANZf1QXsNrY_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ANZf1QXsNrY_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ANZf1QXsNrY_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ANZf1QXsNrY_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_aYe-2Glruu4_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_aYe-2Glruu4_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9Yb9OEVwups_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9Yb9OEVwups_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_aYe-2Glruu4_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_aYe-2Glruu4_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_aYe-2Glruu4_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_aYe-2Glruu4_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9v2WSpn4FCw_5.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9v2WSpn4FCw_5.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_94ROf10d1iA_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_94ROf10d1iA_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9v2WSpn4FCw_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9v2WSpn4FCw_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9v2WSpn4FCw_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9v2WSpn4FCw_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9v2WSpn4FCw_10.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9v2WSpn4FCw_10.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9v2WSpn4FCw_6.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9v2WSpn4FCw_6.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_94ROf10d1iA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_94ROf10d1iA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_9v2WSpn4FCw_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_9v2WSpn4FCw_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_94ROf10d1iA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_94ROf10d1iA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_8rupdevqfuI_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_8rupdevqfuI_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_94ROf10d1iA_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_94ROf10d1iA_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_6Uf9XBUD3wE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_6Uf9XBUD3wE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_7yW9c7t8Hq0_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_7yW9c7t8Hq0_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_7yW9c7t8Hq0_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_7yW9c7t8Hq0_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_7yW9c7t8Hq0_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_7yW9c7t8Hq0_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_6wFJhmhNeeg_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_6wFJhmhNeeg_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_8izVTDgBQPc_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_8izVTDgBQPc_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_8izVTDgBQPc_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_8izVTDgBQPc_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_8rupdevqfuI_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_8rupdevqfuI_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_8rupdevqfuI_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_8rupdevqfuI_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_6kRPHamGDSo_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_6kRPHamGDSo_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_4ydjOX3pWds_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_4ydjOX3pWds_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_5Ju9q1N2x0E_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_5Ju9q1N2x0E_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_6Uf9XBUD3wE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_6Uf9XBUD3wE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_6kRPHamGDSo_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_6kRPHamGDSo_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_6kRPHamGDSo_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_6kRPHamGDSo_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_7.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_7.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_3N2G21U7guk_6.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_3N2G21U7guk_6.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_8.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_8.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_3ahg_eQZhxs_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_3ahg_eQZhxs_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_3N2G21U7guk_5.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_3N2G21U7guk_5.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_4dXC1cC7crw_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_4dXC1cC7crw_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_3ahg_eQZhxs_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_3ahg_eQZhxs_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_2Z9SjI131jA_9.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_2Z9SjI131jA_9.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_4ydjOX3pWds_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_4ydjOX3pWds_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_5NW0zDu6IYM_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_5NW0zDu6IYM_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_60LLKmpgzRM_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_60LLKmpgzRM_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_FfwKrQyQ7WU_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_FfwKrQyQ7WU_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_FfwKrQyQ7WU_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_FfwKrQyQ7WU_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_fey-8bOR95E_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_fey-8bOR95E_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_FfwKrQyQ7WU_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_FfwKrQyQ7WU_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Fc1qk52SaKY_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Fc1qk52SaKY_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Fc1qk52SaKY_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Fc1qk52SaKY_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_fey-8bOR95E_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_fey-8bOR95E_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_fey-8bOR95E_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_fey-8bOR95E_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_fey-8bOR95E_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_fey-8bOR95E_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_eVMSeElk81Q_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_eVMSeElk81Q_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_doM_LWo-74A_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_doM_LWo-74A_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_DX1IK3z1w10_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_DX1IK3z1w10_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_e838BE_MH6s_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_e838BE_MH6s_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_e838BE_MH6s_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_e838BE_MH6s_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_e8NQ2NH0nc8_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_e8NQ2NH0nc8_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_e8NQ2NH0nc8_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_e8NQ2NH0nc8_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_eVMSeElk81Q_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_eVMSeElk81Q_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_eVMSeElk81Q_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_eVMSeElk81Q_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_e838BE_MH6s_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_e838BE_MH6s_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_e838BE_MH6s_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_e838BE_MH6s_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_dfNdpy8TUzA_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_dfNdpy8TUzA_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Cg2u_Ldjv8g_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Cg2u_Ldjv8g_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_doM_LWo-74A_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_doM_LWo-74A_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_dfNdpy8TUzA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_dfNdpy8TUzA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_doM_LWo-74A_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_doM_LWo-74A_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Cg2u_Ldjv8g_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Cg2u_Ldjv8g_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_dfNdpy8TUzA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_dfNdpy8TUzA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_doM_LWo-74A_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_doM_LWo-74A_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_doM_LWo-74A_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_doM_LWo-74A_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_bQS8eAXAhyE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_bQS8eAXAhyE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_BGf5nCdzPOc_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_BGf5nCdzPOc_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_biROWEwkDQQ_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_biROWEwkDQQ_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_bQS8eAXAhyE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_bQS8eAXAhyE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_bIx4DwkZxFY_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_bIx4DwkZxFY_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_BGf5nCdzPOc_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_BGf5nCdzPOc_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_bIx4DwkZxFY_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_bIx4DwkZxFY_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_bIx4DwkZxFY_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_bIx4DwkZxFY_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_bQS8eAXAhyE_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_bQS8eAXAhyE_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_cB-Xh8H_7-Q_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_cB-Xh8H_7-Q_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_k4dxAlI5N-k_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_k4dxAlI5N-k_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_K6OFDxBU370_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_K6OFDxBU370_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_JYVXM0qNQAg_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_JYVXM0qNQAg_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_jziI_cuN_H8_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_jziI_cuN_H8_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_JT1XJnVmABo_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_JT1XJnVmABo_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_JT1XJnVmABo_5.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_JT1XJnVmABo_5.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_JYVXM0qNQAg_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_JYVXM0qNQAg_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_jziI_cuN_H8_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_jziI_cuN_H8_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_k4dxAlI5N-k_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_k4dxAlI5N-k_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_jziI_cuN_H8_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_jziI_cuN_H8_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Jn9r0avp0fY_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Jn9r0avp0fY_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Jn9r0avp0fY_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Jn9r0avp0fY_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_im4Qxn3GQvo_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_im4Qxn3GQvo_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_J6X3rVU1H-c_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_J6X3rVU1H-c_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_JT1XJnVmABo_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_JT1XJnVmABo_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_J6X3rVU1H-c_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_J6X3rVU1H-c_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_im4Qxn3GQvo_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_im4Qxn3GQvo_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Jn9r0avp0fY_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Jn9r0avp0fY_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Jn9r0avp0fY_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Jn9r0avp0fY_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_JT1XJnVmABo_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_JT1XJnVmABo_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_im4Qxn3GQvo_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_im4Qxn3GQvo_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Ie5koh4qvJc_6.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Ie5koh4qvJc_6.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_HY9vPoHbgaI_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_HY9vPoHbgaI_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_iFgSjUqI7iM_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_iFgSjUqI7iM_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_HY9vPoHbgaI_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_HY9vPoHbgaI_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_HY9vPoHbgaI_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_HY9vPoHbgaI_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Ie5koh4qvJc_12.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Ie5koh4qvJc_12.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_HY9vPoHbgaI_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_HY9vPoHbgaI_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_IH2KrGjKXw0_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_IH2KrGjKXw0_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_iFgSjUqI7iM_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_iFgSjUqI7iM_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_GY3f6ckBVkA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_GY3f6ckBVkA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_GY3f6ckBVkA_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_GY3f6ckBVkA_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_GY3f6ckBVkA_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_GY3f6ckBVkA_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_gSwv8hZGM-s_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_gSwv8hZGM-s_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_gSwv8hZGM-s_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_gSwv8hZGM-s_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_GbUV3TXUzeQ_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_GbUV3TXUzeQ_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_GY3f6ckBVkA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_GY3f6ckBVkA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_GbUV3TXUzeQ_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_GbUV3TXUzeQ_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_gwmVjvR-sVs_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_gwmVjvR-sVs_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_gwmVjvR-sVs_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_gwmVjvR-sVs_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_FfwKrQyQ7WU_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_FfwKrQyQ7WU_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_s5b8viFsVJE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_s5b8viFsVJE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_s6-SbDSZzEU_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_s6-SbDSZzEU_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_s5b8viFsVJE_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_s5b8viFsVJE_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_s6-SbDSZzEU_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_s6-SbDSZzEU_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_SQDuF0qxGQw_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_SQDuF0qxGQw_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UJcnNfeCN1c_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UJcnNfeCN1c_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_SlsXsqotUis_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_SlsXsqotUis_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_s5b8viFsVJE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_s5b8viFsVJE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_SQDuF0qxGQw_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_SQDuF0qxGQw_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_sUJ4a74Skk8_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_sUJ4a74Skk8_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_RaUSISlnhKw_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_RaUSISlnhKw_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_SQDuF0qxGQw_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_SQDuF0qxGQw_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_RaUSISlnhKw_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_RaUSISlnhKw_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_QwsQ8ejbMKg_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_QwsQ8ejbMKg_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_POaIGvLsp5M_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_POaIGvLsp5M_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_QwsQ8ejbMKg_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_QwsQ8ejbMKg_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_pNwQ9Tu_bCs_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_pNwQ9Tu_bCs_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_r6laJv1-HMg_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_r6laJv1-HMg_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_qlbazHayULg_8.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_qlbazHayULg_8.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_POaIGvLsp5M_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_POaIGvLsp5M_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_RaUSISlnhKw_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_RaUSISlnhKw_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_PdwxeMPXOCk_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_PdwxeMPXOCk_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_PdwxeMPXOCk_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_PdwxeMPXOCk_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_NP0lwB-_-og_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_NP0lwB-_-og_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_pNwQ9Tu_bCs_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_pNwQ9Tu_bCs_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_nOIBJHkqrE8_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_nOIBJHkqrE8_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_o5AIp2Yc01M_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_o5AIp2Yc01M_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_o5AIp2Yc01M_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_o5AIp2Yc01M_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_osxmQReE_2o_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_osxmQReE_2o_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_pNwQ9Tu_bCs_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_pNwQ9Tu_bCs_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_PdwxeMPXOCk_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_PdwxeMPXOCk_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_NGE9ynTJABg_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_NGE9ynTJABg_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_K6OFDxBU370_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_K6OFDxBU370_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_KxlqB3j0zys_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_KxlqB3j0zys_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ldCQ6N9G6Mk_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ldCQ6N9G6Mk_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_KxlqB3j0zys_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_KxlqB3j0zys_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_NGE9ynTJABg_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_NGE9ynTJABg_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_mX-xs3OVhTs_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_mX-xs3OVhTs_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_miqLU2739dk_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_miqLU2739dk_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_NGE9ynTJABg_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_NGE9ynTJABg_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_mX-xs3OVhTs_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_mX-xs3OVhTs_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_yFw_kO7DF-Y_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_yFw_kO7DF-Y_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_ZgT7yq2jsBk_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_ZgT7yq2jsBk_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_zHwJG8Rrx6c_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_zHwJG8Rrx6c_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_zHwJG8Rrx6c_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_zHwJG8Rrx6c_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_yFw_kO7DF-Y_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_yFw_kO7DF-Y_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_yFw_kO7DF-Y_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_yFw_kO7DF-Y_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_zHwJG8Rrx6c_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_zHwJG8Rrx6c_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Y5JcZQ0xg4Y_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Y5JcZQ0xg4Y_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_zHwJG8Rrx6c_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_zHwJG8Rrx6c_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_xrhWli_R98g_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_xrhWli_R98g_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_XC_SiJszQx0_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_XC_SiJszQx0_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Wy2-my19YnY_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Wy2-my19YnY_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Xsn9zT-05ns_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Xsn9zT-05ns_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Y5JcZQ0xg4Y_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Y5JcZQ0xg4Y_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Xsn9zT-05ns_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Xsn9zT-05ns_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_xrhWli_R98g_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_xrhWli_R98g_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Y5JcZQ0xg4Y_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Y5JcZQ0xg4Y_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Y5JcZQ0xg4Y_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Y5JcZQ0xg4Y_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_VXgRfsVd_o0_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_VXgRfsVd_o0_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_Wy2-my19YnY_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_Wy2-my19YnY_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_VXgRfsVd_o0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_VXgRfsVd_o0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_WpZ1rWHOCAQ_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_WpZ1rWHOCAQ_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_WpZ1rWHOCAQ_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_WpZ1rWHOCAQ_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_VXgRfsVd_o0_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_VXgRfsVd_o0_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_vv6nrZ2myXw_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_vv6nrZ2myXw_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_wnB2cjd6zbE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_wnB2cjd6zbE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_WpZ1rWHOCAQ_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_WpZ1rWHOCAQ_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_vv6nrZ2myXw_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_vv6nrZ2myXw_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_vv6nrZ2myXw_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_vv6nrZ2myXw_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_vv6nrZ2myXw_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_vv6nrZ2myXw_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UOSlDydo94E_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UOSlDydo94E_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_uqRLEByE6pU_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_uqRLEByE6pU_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_V3Y9L4UOcpk_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_V3Y9L4UOcpk_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UYh88SRZC24_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UYh88SRZC24_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_uqRLEByE6pU_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_uqRLEByE6pU_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UYh88SRZC24_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UYh88SRZC24_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_uqRLEByE6pU_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_uqRLEByE6pU_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UOSlDydo94E_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UOSlDydo94E_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UOSlDydo94E_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UOSlDydo94E_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_TNoaOTrTkTQ_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_TNoaOTrTkTQ_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_TNoaOTrTkTQ_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_TNoaOTrTkTQ_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_T92R7xjce34_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_T92R7xjce34_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_UJcnNfeCN1c_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_UJcnNfeCN1c_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_sZe3IB1OVfw_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_sZe3IB1OVfw_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q1_TNoaOTrTkTQ_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q1_TNoaOTrTkTQ_2.csv'
# ...
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_PK8YIUaV3Xw_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_PK8YIUaV3Xw_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_pkz8OkWhwnk_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_pkz8OkWhwnk_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_oTi57hZfArE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_oTi57hZfArE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_prUUays30Mg_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_prUUays30Mg_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_NP0lwB-_-og_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_NP0lwB-_-og_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_OoxI6k0Qsno_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_OoxI6k0Qsno_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_oTi57hZfArE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_oTi57hZfArE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_NzJjMGJg1wE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_NzJjMGJg1wE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_nGkpcWNAxDU_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_nGkpcWNAxDU_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_OgkB7PfqWzA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_OgkB7PfqWzA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_OgkB7PfqWzA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_OgkB7PfqWzA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_oTi57hZfArE_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_oTi57hZfArE_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vBHoSz8cJIE_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vBHoSz8cJIE_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_VCSDjQxAJzc_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_VCSDjQxAJzc_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vBHoSz8cJIE_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vBHoSz8cJIE_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vBHoSz8cJIE_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vBHoSz8cJIE_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vBHoSz8cJIE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vBHoSz8cJIE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_VCSDjQxAJzc_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_VCSDjQxAJzc_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_VCSDjQxAJzc_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_VCSDjQxAJzc_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Xf2fox7zhCQ_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Xf2fox7zhCQ_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vpTguZtJAFA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vpTguZtJAFA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vJ77eDxHezE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vJ77eDxHezE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Ury1cdB79s0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Ury1cdB79s0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_u_7b9CwyM8Q_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_u_7b9CwyM8Q_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vJ77eDxHezE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vJ77eDxHezE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_v3Nl5rUxLqE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_v3Nl5rUxLqE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_v3Nl5rUxLqE_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_v3Nl5rUxLqE_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Ury1cdB79s0_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Ury1cdB79s0_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_V3Y9L4UOcpk_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_V3Y9L4UOcpk_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_uUtnyA6tLnI_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_uUtnyA6tLnI_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_V3Y9L4UOcpk_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_V3Y9L4UOcpk_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_u_7b9CwyM8Q_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_u_7b9CwyM8Q_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vBHoSz8cJIE_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vBHoSz8cJIE_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UaYYMRkHMYc_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UaYYMRkHMYc_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UbKAl4roB8k_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UbKAl4roB8k_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_TOXg4-ZGb-g_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_TOXg4-ZGb-g_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UbKAl4roB8k_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UbKAl4roB8k_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UaYYMRkHMYc_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UaYYMRkHMYc_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UbKAl4roB8k_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UbKAl4roB8k_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UpHutdJvZMI_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UpHutdJvZMI_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UaYYMRkHMYc_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UaYYMRkHMYc_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UpHutdJvZMI_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UpHutdJvZMI_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_UpHutdJvZMI_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_UpHutdJvZMI_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_TOXg4-ZGb-g_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_TOXg4-ZGb-g_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_TOXg4-ZGb-g_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_TOXg4-ZGb-g_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Tc684nD8CEA_4.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Tc684nD8CEA_4.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Tc684nD8CEA_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Tc684nD8CEA_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Tc684nD8CEA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Tc684nD8CEA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Tc684nD8CEA_3.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Tc684nD8CEA_3.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_TcFVq0leii4_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_TcFVq0leii4_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Tjno89OVuRI_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Tjno89OVuRI_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_yC0fAQxGgr0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_yC0fAQxGgr0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Y1F0c3zgMJo_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Y1F0c3zgMJo_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_yC0fAQxGgr0_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_yC0fAQxGgr0_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Y1F0c3zgMJo_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Y1F0c3zgMJo_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4__BK2o77sTc0_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4__BK2o77sTc0_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_YAAxPW1GB7w_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_YAAxPW1GB7w_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_YAAxPW1GB7w_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_YAAxPW1GB7w_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_XWk5XUEBXmg_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_XWk5XUEBXmg_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_XWk5XUEBXmg_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_XWk5XUEBXmg_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_XPLYvpyfKUM_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_XPLYvpyfKUM_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Xlv4PPGrRRs_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Xlv4PPGrRRs_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_xgtwQGeB6_0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_xgtwQGeB6_0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_XPLYvpyfKUM_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_XPLYvpyfKUM_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Xf2fox7zhCQ_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Xf2fox7zhCQ_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_xrhWli_R98g_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_xrhWli_R98g_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Xlv4PPGrRRs_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Xlv4PPGrRRs_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_YhXRyOl5pi0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_YhXRyOl5pi0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vpTguZtJAFA_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vpTguZtJAFA_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_Xf2fox7zhCQ_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_Xf2fox7zhCQ_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_V_jbWvQNh5c_1.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_V_jbWvQNh5c_1.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_V_jbWvQNh5c_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_V_jbWvQNh5c_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_XC_SiJszQx0_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_XC_SiJszQx0_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_wzSr6qR3Ra0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_wzSr6qR3Ra0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_XC_SiJszQx0_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_XC_SiJszQx0_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_VXh4IaR5C6s_0.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_VXh4IaR5C6s_0.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_vpTguZtJAFA_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_vpTguZtJAFA_2.csv'
# Arquivo '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MIDI EMOPIA/Q4_xrhWli_R98g_2.mid' convertido para '/content/drive/MyDrive/INF 420 - IA/TRABALHO FINAL/MUSICAS/EMOPIA/CSV/Q4_xrhWli_R98g_2.csv'
